# %%
# !pip install -U langchain-cli
# !pip install -U "langchain[all]"
# !pip install pypdf
# !pip install chroma

# %% [markdown]
# Create the app

# %%
from dotenv import load_dotenv

load_dotenv()

# Or if you are in Colab, uncoment below and add your api key
import os
# os.environ["OPENAI_API_KEY"] = "your-api-key"

# %%
# !yes|langchain app new chat-with-pdf --package rag-chroma
# Out:
# Would you like to install these templates into your environment with pip? [y/N]: Adding https://github.com/langchain-ai/langchain.git@master...
#  - Downloaded templates/rag-chroma to rag-chroma
# Running: pip install -e \
#   chat-with-pdf/packages/rag-chroma
# Obtaining file:///Users/greatmaster/Desktop/projects/oreilly-live-trainings/oreilly_live_training_agents/notebooks/chat-with-pdf/packages/rag-chroma
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Collecting chromadb>=0.4.14 (from rag-chroma==0.1.0)
#   Using cached chromadb-0.4.24-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: langchain<0.2,>=0.1 in /Users/greatmaster/miniconda3/envs/oreilly-agents-test-env/lib/python3.10/site-packages (from rag-chroma==0.1.0) (0.1.12)
# Requirement already satisfied: langchain-text-splitters<0.1,>=0.0.1 in /Users/greatmaster/miniconda3/envs/oreilly-agents-test-env/lib/python3.10/site-packages (from rag-chroma==0.1.0) (0.0.1)
# Requirement already satisfied: openai<2 in /Users/greatmaster/miniconda3/envs/oreilly-agents-test-env/lib/python3.10/site-packages (from rag-chroma==0.1.0) (1.13.3)
# Requirement already satisfied: tiktoken>=0.5.1 in /Users/greatmaster/miniconda3/envs/oreilly-agents-test-env/lib/python3.10/site-packages (from rag-chroma==0.1.0) (0.6.0)
# Requirement already satisfied: build>=1.0.3 in /Users/greatmaster/miniconda3/envs/oreilly-agents-test-env/lib/python3.10/site-packages (from chromadb>=0.4.14->rag-chroma==0.1.0) (1.1.1)
# Requirement already satisfied: requests>=2.28 in /Users/greatmaster/miniconda3/envs/oreilly-agents-test-env/lib/python3.10/site-packages (from chromadb>=0.4.14->rag-chroma==0.1.0) (2.31.0)
# Requirement already satisfied: pydantic>=1.9 in /Users/greatmaster/miniconda3/envs/oreilly-agents-test-env/lib/python3.10/site-packages (from chromadb>=0.4.14->rag-chroma==0.1.0) (2.6.4)
# Collecting chroma-hnswlib==0.7.3 (from chromadb>=0.4.14->rag-chroma==0.1.0)
#   Using cached chroma_hnswlib-0.7.3-cp310-cp310-macosx_11_0_arm64.whl.metadata (252 bytes)
# Requirement already satisfied: fastapi>=0.95.2 in /Users/greatmaster/miniconda3/envs/oreilly-agents-test-env/lib/python3.10/site-packages (from chromadb>=0.4.14->rag-chroma==0.1.0) (0.110.0)
# Requirement already satisfied: uvicorn>=0.18.3 in /Users/greatmaster/miniconda3/envs/oreilly-agents-test-env/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb>=0.4.14->rag-chroma==0.1.0) (0.23.2)
# Requirement already satisfied: numpy>=1.22.5 in /Users/greatmaster/miniconda3/envs/oreilly-agents-test-env/lib/python3.10/site-packages (from chromadb>=0.4.14->rag-chroma==0.1.0) (1.26.4)
# Collecting posthog>=2.4.0 (from chromadb>=0.4.14->rag-chroma==0.1.0)
#   Using cached posthog-3.5.0-py2.py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: typing-extensions>=4.5.0 in /Users/greatmaster/miniconda3/envs/oreilly-agents-test-env/lib/python3.10/site-packages (from chromadb>=0.4.14->rag-chroma==0.1.0) (4.10.0)
# Collecting pulsar-client>=3.1.0 (from chromadb>=0.4.14->rag-chroma==0.1.0)
#   Using cached pulsar_client-3.4.0-cp310-cp310-macosx_10_15_universal2.whl.metadata (1.0 kB)
# Collecting onnxruntime>=1.14.1 (from chromadb>=0.4.14->rag-chroma==0.1.0)
#   Using cached onnxruntime-1.17.1-cp310-cp310-macosx_11_0_universal2.whl.metadata (4.2 kB)
# Collecting opentelemetry-api>=1.2.0 (from chromadb>=0.4.14->rag-chroma==0.1.0)
#   Using cached opentelemetry_api-1.23.0-py3-none-any.whl.metadata (1.4 kB)
# Collecting opentelemetry-exporter-otlp-proto-grpc>=1.2.0 (from chromadb>=0.4.14->rag-chroma==0.1.0)
#   Using cached opentelemetry_exporter_otlp_proto_grpc-1.23.0-py3-none-any.whl.metadata (2.2 kB)
# Collecting opentelemetry-instrumentation-fastapi>=0.41b0 (from chromadb>=0.4.14->rag-chroma==0.1.0)
#   Using cached opentelemetry_instrumentation_fastapi-0.44b0-py3-none-any.whl.metadata (2.3 kB)
# Collecting opentelemetry-sdk>=1.2.0 (from chromadb>=0.4.14->rag-chroma==0.1.0)
#   Using cached opentelemetry_sdk-1.23.0-py3-none-any.whl.metadata (1.4 kB)
# Collecting tokenizers>=0.13.2 (from chromadb>=0.4.14->rag-chroma==0.1.0)
#   Using cached tokenizers-0.15.2-cp310-cp310-macosx_11_0_arm64.whl.metadata (6.7 kB)
# Collecting pypika>=0.48.9 (from chromadb>=0.4.14->rag-chroma==0.1.0)
#   Using cached PyPika-0.48.9-py2.py3-none-any.whl
# Requirement already satisfied: tqdm>=4.65.0 in /Users/greatmaster/miniconda3/envs/oreilly-agents-test-env/lib/python3.10/site-packages (from chromadb>=0.4.14->rag-chroma==0.1.0) (4.66.2)
# Requirement already satisfied: overrides>=7.3.1 in /Users/greatmaster/miniconda3/envs/oreilly-agents-test-env/lib/python3.10/site-packages (from chromadb>=0.4.14->rag-chroma==0.1.0) (7.7.0)
# Collecting importlib-resources (from chromadb>=0.4.14->rag-chroma==0.1.0)
#   Using cached importlib_resources-6.3.0-py3-none-any.whl.metadata (3.9 kB)
# Collecting grpcio>=1.58.0 (from chromadb>=0.4.14->rag-chroma==0.1.0)
#   Using cached grpcio-1.62.1-cp310-cp310-macosx_12_0_universal2.whl.metadata (4.0 kB)
# Collecting bcrypt>=4.0.1 (from chromadb>=0.4.14->rag-chroma==0.1.0)
#   Using cached bcrypt-4.1.2-cp39-abi3-macosx_10_12_universal2.whl.metadata (9.5 kB)
# Requirement already satisfied: typer>=0.9.0 in /Users/greatmaster/miniconda3/envs/oreilly-agents-test-env/lib/python3.10/site-packages (from chromadb>=0.4.14->rag-chroma==0.1.0) (0.9.0)
# Collecting kubernetes>=28.1.0 (from chromadb>=0.4.14->rag-chroma==0.1.0)
#   Using cached kubernetes-29.0.0-py2.py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: tenacity>=8.2.3 in /Users/greatmaster/miniconda3/envs/oreilly-agents-test-env/lib/python3.10/site-packages (from chromadb>=0.4.14->rag-chroma==0.1.0) (8.2.3)
# Requirement already satisfied: PyYAML>=6.0.0 in /Users/greatmaster/miniconda3/envs/oreilly-agents-test-env/lib/python3.10/site-packages (from chromadb>=0.4.14->rag-chroma==0.1.0) (6.0.1)
# Collecting mmh3>=4.0.1 (from chromadb>=0.4.14->rag-chroma==0.1.0)
#   Using cached mmh3-4.1.0-cp310-cp310-macosx_11_0_arm64.whl.metadata (13 kB)
# Requirement already satisfied: orjson>=3.9.12 in /Users/greatmaster/miniconda3/envs/oreilly-agents-test-env/lib/python3.10/site-packages (from chromadb>=0.4.14->rag-chroma==0.1.0) (3.9.15)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /Users/greatmaster/miniconda3/envs/oreilly-agents-test-env/lib/python3.10/site-packages (from langchain<0.2,>=0.1->rag-chroma==0.1.0) (2.0.28)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /Users/greatmaster/miniconda3/envs/oreilly-agents-test-env/lib/python3.10/site-packages (from langchain<0.2,>=0.1->rag-chroma==0.1.0) (3.9.3)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /Users/greatmaster/miniconda3/envs/oreilly-agents-test-env/lib/python3.10/site-packages (from langchain<0.2,>=0.1->rag-chroma==0.1.0) (4.0.3)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /Users/greatmaster/miniconda3/envs/oreilly-agents-test-env/lib/python3.10/site-packages (from langchain<0.2,>=0.1->rag-chroma==0.1.0) (0.6.4)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /Users/greatmaster/miniconda3/envs/oreilly-agents-test-env/lib/python3.10/site-packages (from langchain<0.2,>=0.1->rag-chroma==0.1.0) (1.33)
# Requirement already satisfied: langchain-community<0.1,>=0.0.28 in /Users/greatmaster/miniconda3/envs/oreilly-agents-test-env/lib/python3.10/site-packages (from langchain<0.2,>=0.1->rag-chroma==0.1.0) (0.0.28)
# Requirement already satisfied: langchain-core<0.2.0,>=0.1.31 in /Users/greatmaster/miniconda3/envs/oreilly-agents-test-env/lib/python3.10/site-packages (from langchain<0.2,>=0.1->rag-chroma==0.1.0) (0.1.31)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in /Users/greatmaster/miniconda3/envs/oreilly-agents-test-env/lib/python3.10/site-packages (from langchain<0.2,>=0.1->rag-chroma==0.1.0) (0.1.24)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/greatmaster/miniconda3/envs/oreilly-agents-test-env/lib/python3.10/site-packages (from openai<2->rag-chroma==0.1.0) (4.3.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/greatmaster/miniconda3/envs/oreilly-agents-test-env/lib/python3.10/site-packages (from openai<2->rag-chroma==0.1.0) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/greatmaster/miniconda3/envs/oreilly-agents-test-env/lib/python3.10/site-packages (from openai<2->rag-chroma==0.1.0) (0.27.0)
# Requirement already satisfied: sniffio in /Users/greatmaster/miniconda3/envs/oreilly-agents-test-env/lib/python3.10/site-packages (from openai<2->rag-chroma==0.1.0) (1.3.1)
# Requirement already satisfied: regex>=2022.1.18 in /Users/greatmaster/miniconda3/envs/oreilly-agents-test-env/lib/python3.10/site-packages (from tiktoken>=0.5.1->rag-chroma==0.1.0) (2023.12.25)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/greatmaster/miniconda3/envs/oreilly-agents-test-env/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain<0.2,>=0.1->rag-chroma==0.1.0) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /Users/greatmaster/miniconda3/envs/oreilly-agents-test-env/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain<0.2,>=0.1->rag-chroma==0.1.0) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/greatmaster/miniconda3/envs/oreilly-agents-test-env/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain<0.2,>=0.1->rag-chroma==0.1.0) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/greatmaster/miniconda3/envs/oreilly-agents-test-env/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain<0.2,>=0.1->rag-chroma==0.1.0) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/greatmaster/miniconda3/envs/oreilly-agents-test-env/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain<0.2,>=0.1->rag-chroma==0.1.0) (1.9.4)
# Requirement already satisfied: idna>=2.8 in /Users/greatmaster/miniconda3/envs/oreilly-agents-test-env/lib/python3.10/site-packages (from anyio<5,>=3.5.0->openai<2->rag-chroma==0.1.0) (3.6)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/greatmaster/miniconda3/envs/oreilly-agents-test-env/lib/python3.10/site-packages (from anyio<5,>=3.5.0->openai<2->rag-chroma==0.1.0) (1.2.0)
# Requirement already satisfied: packaging>=19.0 in /Users/greatmaster/miniconda3/envs/oreilly-agents-test-env/lib/python3.10/site-packages (from build>=1.0.3->chromadb>=0.4.14->rag-chroma==0.1.0) (23.2)
# Requirement already satisfied: pyproject_hooks in /Users/greatmaster/miniconda3/envs/oreilly-agents-test-env/lib/python3.10/site-packages (from build>=1.0.3->chromadb>=0.4.14->rag-chroma==0.1.0) (1.0.0)
# Requirement already satisfied: tomli>=1.1.0 in /Users/greatmaster/miniconda3/envs/oreilly-agents-test-env/lib/python3.10/site-packages (from build>=1.0.3->chromadb>=0.4.14->rag-chroma==0.1.0) (2.0.1)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/greatmaster/miniconda3/envs/oreilly-agents-test-env/lib/python3.10/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain<0.2,>=0.1->rag-chroma==0.1.0) (3.21.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /Users/greatmaster/miniconda3/envs/oreilly-agents-test-env/lib/python3.10/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain<0.2,>=0.1->rag-chroma==0.1.0) (0.9.0)
# Requirement already satisfied: starlette<0.37.0,>=0.36.3 in /Users/greatmaster/miniconda3/envs/oreilly-agents-test-env/lib/python3.10/site-packages (from fastapi>=0.95.2->chromadb>=0.4.14->rag-chroma==0.1.0) (0.36.3)
# Requirement already satisfied: certifi in /Users/greatmaster/miniconda3/envs/oreilly-agents-test-env/lib/python3.10/site-packages (from httpx<1,>=0.23.0->openai<2->rag-chroma==0.1.0) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in /Users/greatmaster/miniconda3/envs/oreilly-agents-test-env/lib/python3.10/site-packages (from httpx<1,>=0.23.0->openai<2->rag-chroma==0.1.0) (1.0.4)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/greatmaster/miniconda3/envs/oreilly-agents-test-env/lib/python3.10/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai<2->rag-chroma==0.1.0) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/greatmaster/miniconda3/envs/oreilly-agents-test-env/lib/python3.10/site-packages (from jsonpatch<2.0,>=1.33->langchain<0.2,>=0.1->rag-chroma==0.1.0) (2.4)
# Requirement already satisfied: six>=1.9.0 in /Users/greatmaster/miniconda3/envs/oreilly-agents-test-env/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb>=0.4.14->rag-chroma==0.1.0) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /Users/greatmaster/miniconda3/envs/oreilly-agents-test-env/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb>=0.4.14->rag-chroma==0.1.0) (2.9.0.post0)
# Collecting google-auth>=1.0.1 (from kubernetes>=28.1.0->chromadb>=0.4.14->rag-chroma==0.1.0)
#   Using cached google_auth-2.28.2-py2.py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /Users/greatmaster/miniconda3/envs/oreilly-agents-test-env/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb>=0.4.14->rag-chroma==0.1.0) (1.7.0)
# Requirement already satisfied: requests-oauthlib in /Users/greatmaster/miniconda3/envs/oreilly-agents-test-env/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb>=0.4.14->rag-chroma==0.1.0) (1.4.0)
# Requirement already satisfied: oauthlib>=3.2.2 in /Users/greatmaster/miniconda3/envs/oreilly-agents-test-env/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb>=0.4.14->rag-chroma==0.1.0) (3.2.2)
# Requirement already satisfied: urllib3>=1.24.2 in /Users/greatmaster/miniconda3/envs/oreilly-agents-test-env/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb>=0.4.14->rag-chroma==0.1.0) (2.2.1)
# Collecting coloredlogs (from onnxruntime>=1.14.1->chromadb>=0.4.14->rag-chroma==0.1.0)
#   Using cached coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Collecting flatbuffers (from onnxruntime>=1.14.1->chromadb>=0.4.14->rag-chroma==0.1.0)
#   Using cached flatbuffers-24.3.7-py2.py3-none-any.whl.metadata (849 bytes)
# Collecting protobuf (from onnxruntime>=1.14.1->chromadb>=0.4.14->rag-chroma==0.1.0)
#   Using cached protobuf-4.25.3-cp37-abi3-macosx_10_9_universal2.whl.metadata (541 bytes)
# Collecting sympy (from onnxruntime>=1.14.1->chromadb>=0.4.14->rag-chroma==0.1.0)
#   Using cached sympy-1.12-py3-none-any.whl.metadata (12 kB)
# Collecting deprecated>=1.2.6 (from opentelemetry-api>=1.2.0->chromadb>=0.4.14->rag-chroma==0.1.0)
#   Using cached Deprecated-1.2.14-py2.py3-none-any.whl.metadata (5.4 kB)
# Collecting importlib-metadata<7.0,>=6.0 (from opentelemetry-api>=1.2.0->chromadb>=0.4.14->rag-chroma==0.1.0)
#   Using cached importlib_metadata-6.11.0-py3-none-any.whl.metadata (4.9 kB)
# Collecting googleapis-common-protos~=1.52 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb>=0.4.14->rag-chroma==0.1.0)
#   Using cached googleapis_common_protos-1.63.0-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting opentelemetry-exporter-otlp-proto-common==1.23.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb>=0.4.14->rag-chroma==0.1.0)
#   Using cached opentelemetry_exporter_otlp_proto_common-1.23.0-py3-none-any.whl.metadata (1.7 kB)
# Collecting opentelemetry-proto==1.23.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb>=0.4.14->rag-chroma==0.1.0)
#   Using cached opentelemetry_proto-1.23.0-py3-none-any.whl.metadata (2.2 kB)
# Collecting opentelemetry-instrumentation-asgi==0.44b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.4.14->rag-chroma==0.1.0)
#   Using cached opentelemetry_instrumentation_asgi-0.44b0-py3-none-any.whl.metadata (2.1 kB)
# Collecting opentelemetry-instrumentation==0.44b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.4.14->rag-chroma==0.1.0)
#   Using cached opentelemetry_instrumentation-0.44b0-py3-none-any.whl.metadata (6.1 kB)
# Collecting opentelemetry-semantic-conventions==0.44b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.4.14->rag-chroma==0.1.0)
#   Using cached opentelemetry_semantic_conventions-0.44b0-py3-none-any.whl.metadata (2.2 kB)
# Collecting opentelemetry-util-http==0.44b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.4.14->rag-chroma==0.1.0)
#   Using cached opentelemetry_util_http-0.44b0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: setuptools>=16.0 in /Users/greatmaster/miniconda3/envs/oreilly-agents-test-env/lib/python3.10/site-packages (from opentelemetry-instrumentation==0.44b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.4.14->rag-chroma==0.1.0) (68.2.2)
# Collecting wrapt<2.0.0,>=1.0.0 (from opentelemetry-instrumentation==0.44b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.4.14->rag-chroma==0.1.0)
#   Using cached wrapt-1.16.0-cp310-cp310-macosx_11_0_arm64.whl.metadata (6.6 kB)
# Collecting asgiref~=3.0 (from opentelemetry-instrumentation-asgi==0.44b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.4.14->rag-chroma==0.1.0)
#   Using cached asgiref-3.7.2-py3-none-any.whl.metadata (9.2 kB)
# Collecting monotonic>=1.5 (from posthog>=2.4.0->chromadb>=0.4.14->rag-chroma==0.1.0)
#   Using cached monotonic-1.6-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting backoff>=1.10.0 (from posthog>=2.4.0->chromadb>=0.4.14->rag-chroma==0.1.0)
#   Using cached backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: annotated-types>=0.4.0 in /Users/greatmaster/miniconda3/envs/oreilly-agents-test-env/lib/python3.10/site-packages (from pydantic>=1.9->chromadb>=0.4.14->rag-chroma==0.1.0) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.3 in /Users/greatmaster/miniconda3/envs/oreilly-agents-test-env/lib/python3.10/site-packages (from pydantic>=1.9->chromadb>=0.4.14->rag-chroma==0.1.0) (2.16.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/greatmaster/miniconda3/envs/oreilly-agents-test-env/lib/python3.10/site-packages (from requests>=2.28->chromadb>=0.4.14->rag-chroma==0.1.0) (3.3.2)
# Collecting huggingface_hub<1.0,>=0.16.4 (from tokenizers>=0.13.2->chromadb>=0.4.14->rag-chroma==0.1.0)
#   Using cached huggingface_hub-0.21.4-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /Users/greatmaster/miniconda3/envs/oreilly-agents-test-env/lib/python3.10/site-packages (from typer>=0.9.0->chromadb>=0.4.14->rag-chroma==0.1.0) (8.1.7)
# Collecting httptools>=0.5.0 (from uvicorn[standard]>=0.18.3->chromadb>=0.4.14->rag-chroma==0.1.0)
#   Using cached httptools-0.6.1-cp310-cp310-macosx_10_9_universal2.whl.metadata (3.6 kB)
# Requirement already satisfied: python-dotenv>=0.13 in /Users/greatmaster/miniconda3/envs/oreilly-agents-test-env/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb>=0.4.14->rag-chroma==0.1.0) (1.0.1)
# Collecting uvloop!=0.15.0,!=0.15.1,>=0.14.0 (from uvicorn[standard]>=0.18.3->chromadb>=0.4.14->rag-chroma==0.1.0)
#   Using cached uvloop-0.19.0-cp310-cp310-macosx_10_9_universal2.whl.metadata (4.9 kB)
# Collecting watchfiles>=0.13 (from uvicorn[standard]>=0.18.3->chromadb>=0.4.14->rag-chroma==0.1.0)
#   Using cached watchfiles-0.21.0-cp310-cp310-macosx_11_0_arm64.whl.metadata (4.9 kB)
# Collecting websockets>=10.4 (from uvicorn[standard]>=0.18.3->chromadb>=0.4.14->rag-chroma==0.1.0)
#   Using cached websockets-12.0-cp310-cp310-macosx_11_0_arm64.whl.metadata (6.6 kB)
# Collecting cachetools<6.0,>=2.0.0 (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=0.4.14->rag-chroma==0.1.0)
#   Using cached cachetools-5.3.3-py3-none-any.whl.metadata (5.3 kB)
# Collecting pyasn1-modules>=0.2.1 (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=0.4.14->rag-chroma==0.1.0)
#   Using cached pyasn1_modules-0.3.0-py2.py3-none-any.whl.metadata (3.6 kB)
# Collecting rsa<5,>=3.1.4 (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=0.4.14->rag-chroma==0.1.0)
#   Using cached rsa-4.9-py3-none-any.whl.metadata (4.2 kB)
# Collecting filelock (from huggingface_hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb>=0.4.14->rag-chroma==0.1.0)
#   Using cached filelock-3.13.1-py3-none-any.whl.metadata (2.8 kB)
# Collecting fsspec>=2023.5.0 (from huggingface_hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb>=0.4.14->rag-chroma==0.1.0)
#   Using cached fsspec-2024.2.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting zipp>=0.5 (from importlib-metadata<7.0,>=6.0->opentelemetry-api>=1.2.0->chromadb>=0.4.14->rag-chroma==0.1.0)
#   Using cached zipp-3.18.0-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/greatmaster/miniconda3/envs/oreilly-agents-test-env/lib/python3.10/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain<0.2,>=0.1->rag-chroma==0.1.0) (1.0.0)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime>=1.14.1->chromadb>=0.4.14->rag-chroma==0.1.0)
#   Using cached humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Collecting mpmath>=0.19 (from sympy->onnxruntime>=1.14.1->chromadb>=0.4.14->rag-chroma==0.1.0)
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting pyasn1<0.6.0,>=0.4.6 (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=0.4.14->rag-chroma==0.1.0)
#   Using cached pyasn1-0.5.1-py2.py3-none-any.whl.metadata (8.6 kB)
# Using cached chromadb-0.4.24-py3-none-any.whl (525 kB)
# Using cached chroma_hnswlib-0.7.3-cp310-cp310-macosx_11_0_arm64.whl (197 kB)
# Using cached bcrypt-4.1.2-cp39-abi3-macosx_10_12_universal2.whl (528 kB)
# Using cached grpcio-1.62.1-cp310-cp310-macosx_12_0_universal2.whl (10.0 MB)
# Using cached kubernetes-29.0.0-py2.py3-none-any.whl (1.6 MB)
# Using cached mmh3-4.1.0-cp310-cp310-macosx_11_0_arm64.whl (30 kB)
# Using cached onnxruntime-1.17.1-cp310-cp310-macosx_11_0_universal2.whl (14.8 MB)
# Using cached opentelemetry_api-1.23.0-py3-none-any.whl (58 kB)
# Using cached opentelemetry_exporter_otlp_proto_grpc-1.23.0-py3-none-any.whl (18 kB)
# Using cached opentelemetry_exporter_otlp_proto_common-1.23.0-py3-none-any.whl (17 kB)
# Using cached opentelemetry_proto-1.23.0-py3-none-any.whl (50 kB)
# Using cached opentelemetry_instrumentation_fastapi-0.44b0-py3-none-any.whl (11 kB)
# Using cached opentelemetry_instrumentation-0.44b0-py3-none-any.whl (28 kB)
# Using cached opentelemetry_instrumentation_asgi-0.44b0-py3-none-any.whl (14 kB)
# Using cached opentelemetry_semantic_conventions-0.44b0-py3-none-any.whl (36 kB)
# Using cached opentelemetry_util_http-0.44b0-py3-none-any.whl (6.9 kB)
# Using cached opentelemetry_sdk-1.23.0-py3-none-any.whl (105 kB)
# Using cached posthog-3.5.0-py2.py3-none-any.whl (41 kB)
# Using cached pulsar_client-3.4.0-cp310-cp310-macosx_10_15_universal2.whl (10.9 MB)
# Using cached tokenizers-0.15.2-cp310-cp310-macosx_11_0_arm64.whl (2.4 MB)
# Using cached importlib_resources-6.3.0-py3-none-any.whl (35 kB)
# Using cached backoff-2.2.1-py3-none-any.whl (15 kB)
# Using cached Deprecated-1.2.14-py2.py3-none-any.whl (9.6 kB)
# Using cached google_auth-2.28.2-py2.py3-none-any.whl (186 kB)
# Using cached googleapis_common_protos-1.63.0-py2.py3-none-any.whl (229 kB)
# Using cached httptools-0.6.1-cp310-cp310-macosx_10_9_universal2.whl (149 kB)
# Using cached huggingface_hub-0.21.4-py3-none-any.whl (346 kB)
# Using cached importlib_metadata-6.11.0-py3-none-any.whl (23 kB)
# Using cached monotonic-1.6-py2.py3-none-any.whl (8.2 kB)
# Using cached protobuf-4.25.3-cp37-abi3-macosx_10_9_universal2.whl (394 kB)
# Using cached uvloop-0.19.0-cp310-cp310-macosx_10_9_universal2.whl (1.4 MB)
# Using cached watchfiles-0.21.0-cp310-cp310-macosx_11_0_arm64.whl (418 kB)
# Using cached websockets-12.0-cp310-cp310-macosx_11_0_arm64.whl (121 kB)
# Using cached coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
# Using cached flatbuffers-24.3.7-py2.py3-none-any.whl (26 kB)
# Using cached sympy-1.12-py3-none-any.whl (5.7 MB)
# Using cached asgiref-3.7.2-py3-none-any.whl (24 kB)
# Using cached cachetools-5.3.3-py3-none-any.whl (9.3 kB)
# Using cached fsspec-2024.2.0-py3-none-any.whl (170 kB)
# Using cached humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
# Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Using cached pyasn1_modules-0.3.0-py2.py3-none-any.whl (181 kB)
# Using cached rsa-4.9-py3-none-any.whl (34 kB)
# Using cached wrapt-1.16.0-cp310-cp310-macosx_11_0_arm64.whl (38 kB)
# Using cached zipp-3.18.0-py3-none-any.whl (8.2 kB)
# Using cached filelock-3.13.1-py3-none-any.whl (11 kB)
# Using cached pyasn1-0.5.1-py2.py3-none-any.whl (84 kB)
# Building wheels for collected packages: rag-chroma
#   Building editable for rag-chroma (pyproject.toml) ... done
#   Created wheel for rag-chroma: filename=rag_chroma-0.1.0-py3-none-any.whl size=2916 sha256=605575e42210fcadb879a1e4a7626981908926160c119c731e8c09f7254b494e
#   Stored in directory: /private/var/folders/5l/y8s3fc655417629rqwgxkhx80000gn/T/pip-ephem-wheel-cache-_4da0s23/wheels/11/a7/83/c01d3ad89c12546de7f879a318c85ed6e97fdacf74ffa2d93c
# Successfully built rag-chroma
# Installing collected packages: pypika, mpmath, monotonic, mmh3, flatbuffers, zipp, wrapt, websockets, uvloop, sympy, pyasn1, pulsar-client, protobuf, opentelemetry-util-http, opentelemetry-semantic-conventions, importlib-resources, humanfriendly, httptools, grpcio, fsspec, filelock, chroma-hnswlib, cachetools, bcrypt, backoff, asgiref, watchfiles, rsa, pyasn1-modules, posthog, opentelemetry-proto, importlib-metadata, huggingface_hub, googleapis-common-protos, deprecated, coloredlogs, tokenizers, opentelemetry-exporter-otlp-proto-common, opentelemetry-api, onnxruntime, google-auth, opentelemetry-sdk, opentelemetry-instrumentation, kubernetes, opentelemetry-instrumentation-asgi, opentelemetry-exporter-otlp-proto-grpc, opentelemetry-instrumentation-fastapi, chromadb, rag-chroma
# Successfully installed asgiref-3.7.2 backoff-2.2.1 bcrypt-4.1.2 cachetools-5.3.3 chroma-hnswlib-0.7.3 chromadb-0.4.24 coloredlogs-15.0.1 deprecated-1.2.14 filelock-3.13.1 flatbuffers-24.3.7 fsspec-2024.2.0 google-auth-2.28.2 googleapis-common-protos-1.63.0 grpcio-1.62.1 httptools-0.6.1 huggingface_hub-0.21.4 humanfriendly-10.0 importlib-metadata-6.11.0 importlib-resources-6.3.0 kubernetes-29.0.0 mmh3-4.1.0 monotonic-1.6 mpmath-1.3.0 onnxruntime-1.17.1 opentelemetry-api-1.23.0 opentelemetry-exporter-otlp-proto-common-1.23.0 opentelemetry-exporter-otlp-proto-grpc-1.23.0 opentelemetry-instrumentation-0.44b0 opentelemetry-instrumentation-asgi-0.44b0 opentelemetry-instrumentation-fastapi-0.44b0 opentelemetry-proto-1.23.0 opentelemetry-sdk-1.23.0 opentelemetry-semantic-conventions-0.44b0 opentelemetry-util-http-0.44b0 posthog-3.5.0 protobuf-4.25.3 pulsar-client-3.4.0 pyasn1-0.5.1 pyasn1-modules-0.3.0 pypika-0.48.9 rag-chroma-0.1.0 rsa-4.9 sympy-1.12 tokenizers-0.15.2 uvloop-0.19.0 watchfiles-0.21.0 websockets-12.0 wrapt-1.16.0 zipp-3.18.0
#
# To use this template, add the following to your app:
#
# ```
#
# from rag_chroma import chain as rag_chroma_chain
#
# add_routes(app, rag_chroma_chain, path="/rag-chroma")
# ```
# yes: stdout: Broken pipe

# %%
# !ls ./chat-with-pdf
# Out:
# Dockerfile     README.md      app            packages       pyproject.toml

# %%
# !ls ./chat-with-pdf/app
# Out:
# __init__.py __pycache__ server.py

# %% [markdown]
# Find the `/app/server.py` file and add:
#
# ```
# from rag_conversation import chain as rag_chroma_chain
#
# add_routes(app, rag_chroma_chain, path="/rag-chroma")
# ```

# %% [markdown]
# Optionally you can configure langsmith:
#
# ```
# export LANGCHAIN_TRACING_V2=true
# export LANGCHAIN_API_KEY=<your-api-key>
# export LANGCHAIN_PROJECT=<your-project>  # if not specified, defaults to "default"
# ```

# %% [markdown]
# Now, let's add some data to chat with!
#
# For that let's open the chain.py file that was created in `/packages/rag-chroma/rag-chroma/chain.py`
#
# Let's modify it to accept data releavnt to us, in our case let's set up a chat with a blog article about agents:
#
# - https://lilianweng.github.io/posts/2023-06-23-agent/

# %% [markdown]
# ```
# from langchain_community.document_loaders import WebBaseLoader
# loader = WebBaseLoader("https://lilianweng.github.io/posts/2023-06-23-agent/")
# data = loader.load()
#
# # Split
# from langchain.text_splitter import RecursiveCharacterTextSplitter
# text_splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=0)
# all_splits = text_splitter.split_documents(data)
#
# # Add to vectorDB
# vectorstore = Chroma.from_documents(documents=all_splits,
#                                     collection_name="rag-chroma",
#                                     embedding=OpenAIEmbeddings(),
#                                     )
# retriever = vectorstore.as_retriever()
# ```
#
# The rest of the code should remain the same.

# %% [markdown]
# Now, we can deploy our app:

# %%
! cd chat-with-pdf && langchain serve
# Out:
# INFO:     Will watch for changes in these directories: ['/Users/greatmaster/Desktop/projects/oreilly-live-trainings/oreilly_live_training_agents/notebooks/chat-with-pdf']
# INFO:     Uvicorn running on http://127.0.0.1:8000 (Press CTRL+C to quit)
# INFO:     Started reloader process [32933] using WatchFiles
# /Users/greatmaster/miniconda3/envs/oreilly-agents-test-env/lib/python3.10/site-packages/langchain_core/_api/deprecation.py:117: LangChainDeprecationWarning: The class `langchain_community.embeddings.openai.OpenAIEmbeddings` was deprecated in langchain-community 0.0.9 and will be removed in 0.2.0. An updated version of the class exists in the langchain-openai package and should be used instead. To use it run `pip install -U langchain-openai` and import as `from langchain_openai import OpenAIEmbeddings`.
#   warn_deprecated(
# /Users/greatmaster/miniconda3/envs/oreilly-agents-test-env/lib/python3.10/site-packages/langchain_core/_api/deprecation.py:117: LangChainDeprecationWarning: The class `langchain_community.chat_models.openai.ChatOpenAI` was deprecated in langchain-community 0.0.10 and will be removed in 0.2.0. An updated version of the class exists in the langchain-openai package and should be used instead. To use it run `pip install -U langchain-openai` and import as `from langchain_openai import ChatOpenAI`.
#   warn_deprecated(
# INFO:     Started server process [32943]
# INFO:     Waiting for application startup.
#
#  __          ___      .__   __.   _______      _______. _______ .______     ____    ____  _______
# |  |        /   \     |  \ |  |  /  _____|    /       ||   ____||   _  \    \   \  /   / |   ____|
# |  |       /  ^  \    |   \|  | |  |  __     |   (----`|  |__   |  |_)  |    \   \/   /  |  |__
# |  |      /  /_\  \   |  . `  | |  | |_ |     \   \    |   __|  |      /      \      /   |   __|
# |  `----./  _____  \  |  |\   | |  |__| | .----)   |   |  |____ |  |\  \----.  \    /    |  |____
# |_______/__/     \__\ |__| \__|  \______| |_______/    |_______|| _| `._____|   \__/     |_______|
#
# LANGSERVE: Playground for chain "/rag-chroma/" is live at:
# LANGSERVE:  │
# LANGSERVE:  └──> /rag-chroma/playground/
# LANGSERVE:
# LANGSERVE: See all available routes at /docs/
#
# LANGSERVE: ⚠️ Using pydantic 2.6.4. OpenAPI docs for invoke, batch, stream, stream_log endpoints will not be generated. API endpoints and playground should work as expected. If you need to see the docs, you can downgrade to pydantic 1. For example, `pip install pydantic==1.10.13`. See https://github.com/tiangolo/fastapi/issues/10360 for details.
#
# INFO:     Application startup complete.
# INFO:     127.0.0.1:52414 - "GET /rag-chroma/playground HTTP/1.1" 307 Temporary Redirect
# INFO:     127.0.0.1:52414 - "GET /rag-chroma/playground/ HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52414 - "GET /rag-chroma/playground/assets/index-dbc96538.js HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52416 - "GET /rag-chroma/playground/assets/index-52e8ab2f.css HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52414 - "GET /rag-chroma/playground/favicon.ico HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52414 - "GET /rag-chroma/playground/favicon.ico HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52419 - "POST /rag-chroma/stream_log HTTP/1.1" 200 OK
# Number of requested results 4 is greater than number of elements in index 1, updating n_results = 1
# WARNING:  WatchFiles detected changes in 'app/server.py'. Reloading...
# INFO:     Shutting down
# INFO:     Waiting for application shutdown.
# INFO:     Application shutdown complete.
# INFO:     Finished server process [32943]
# /Users/greatmaster/miniconda3/envs/oreilly-agents-test-env/lib/python3.10/site-packages/langchain_core/_api/deprecation.py:117: LangChainDeprecationWarning: The class `langchain_community.embeddings.openai.OpenAIEmbeddings` was deprecated in langchain-community 0.0.9 and will be removed in 0.2.0. An updated version of the class exists in the langchain-openai package and should be used instead. To use it run `pip install -U langchain-openai` and import as `from langchain_openai import OpenAIEmbeddings`.
#   warn_deprecated(
# /Users/greatmaster/miniconda3/envs/oreilly-agents-test-env/lib/python3.10/site-packages/langchain_core/_api/deprecation.py:117: LangChainDeprecationWarning: The class `langchain_community.chat_models.openai.ChatOpenAI` was deprecated in langchain-community 0.0.10 and will be removed in 0.2.0. An updated version of the class exists in the langchain-openai package and should be used instead. To use it run `pip install -U langchain-openai` and import as `from langchain_openai import ChatOpenAI`.
#   warn_deprecated(
# INFO:     Started server process [33200]
# INFO:     Waiting for application startup.
#
#  __          ___      .__   __.   _______      _______. _______ .______     ____    ____  _______
# |  |        /   \     |  \ |  |  /  _____|    /       ||   ____||   _  \    \   \  /   / |   ____|
# |  |       /  ^  \    |   \|  | |  |  __     |   (----`|  |__   |  |_)  |    \   \/   /  |  |__
# |  |      /  /_\  \   |  . `  | |  | |_ |     \   \    |   __|  |      /      \      /   |   __|
# |  `----./  _____  \  |  |\   | |  |__| | .----)   |   |  |____ |  |\  \----.  \    /    |  |____
# |_______/__/     \__\ |__| \__|  \______| |_______/    |_______|| _| `._____|   \__/     |_______|
#
# LANGSERVE: Playground for chain "/rag-chroma/" is live at:
# LANGSERVE:  │
# LANGSERVE:  └──> /rag-chroma/playground/
# LANGSERVE:
# LANGSERVE: See all available routes at /docs/
#
# LANGSERVE: ⚠️ Using pydantic 2.6.4. OpenAPI docs for invoke, batch, stream, stream_log endpoints will not be generated. API endpoints and playground should work as expected. If you need to see the docs, you can downgrade to pydantic 1. For example, `pip install pydantic==1.10.13`. See https://github.com/tiangolo/fastapi/issues/10360 for details.
#
# INFO:     Application startup complete.
# INFO:     127.0.0.1:52446 - "POST /rag-chroma/stream_log HTTP/1.1" 200 OK
# Number of requested results 4 is greater than number of elements in index 1, updating n_results = 1
# WARNING:  WatchFiles detected changes in 'packages/rag-chroma/rag_chroma/chain.py'. Reloading...
# INFO:     Shutting down
# INFO:     Waiting for application shutdown.
# INFO:     Application shutdown complete.
# INFO:     Finished server process [33200]
# /Users/greatmaster/miniconda3/envs/oreilly-agents-test-env/lib/python3.10/site-packages/langchain_core/_api/deprecation.py:117: LangChainDeprecationWarning: The class `langchain_community.embeddings.openai.OpenAIEmbeddings` was deprecated in langchain-community 0.0.9 and will be removed in 0.2.0. An updated version of the class exists in the langchain-openai package and should be used instead. To use it run `pip install -U langchain-openai` and import as `from langchain_openai import OpenAIEmbeddings`.
#   warn_deprecated(
# /Users/greatmaster/miniconda3/envs/oreilly-agents-test-env/lib/python3.10/site-packages/langchain_core/_api/deprecation.py:117: LangChainDeprecationWarning: The class `langchain_community.chat_models.openai.ChatOpenAI` was deprecated in langchain-community 0.0.10 and will be removed in 0.2.0. An updated version of the class exists in the langchain-openai package and should be used instead. To use it run `pip install -U langchain-openai` and import as `from langchain_openai import ChatOpenAI`.
#   warn_deprecated(
# INFO:     Started server process [33529]
# INFO:     Waiting for application startup.
#
#  __          ___      .__   __.   _______      _______. _______ .______     ____    ____  _______
# |  |        /   \     |  \ |  |  /  _____|    /       ||   ____||   _  \    \   \  /   / |   ____|
# |  |       /  ^  \    |   \|  | |  |  __     |   (----`|  |__   |  |_)  |    \   \/   /  |  |__
# |  |      /  /_\  \   |  . `  | |  | |_ |     \   \    |   __|  |      /      \      /   |   __|
# |  `----./  _____  \  |  |\   | |  |__| | .----)   |   |  |____ |  |\  \----.  \    /    |  |____
# |_______/__/     \__\ |__| \__|  \______| |_______/    |_______|| _| `._____|   \__/     |_______|
#
# LANGSERVE: Playground for chain "/rag-chroma/" is live at:
# LANGSERVE:  │
# LANGSERVE:  └──> /rag-chroma/playground/
# LANGSERVE:
# LANGSERVE: See all available routes at /docs/
#
# LANGSERVE: ⚠️ Using pydantic 2.6.4. OpenAPI docs for invoke, batch, stream, stream_log endpoints will not be generated. API endpoints and playground should work as expected. If you need to see the docs, you can downgrade to pydantic 1. For example, `pip install pydantic==1.10.13`. See https://github.com/tiangolo/fastapi/issues/10360 for details.
#
# INFO:     Application startup complete.
# WARNING:  WatchFiles detected changes in 'packages/rag-chroma/rag_chroma/chain.py'. Reloading...
# INFO:     Shutting down
# INFO:     Waiting for application shutdown.
# INFO:     Application shutdown complete.
# INFO:     Finished server process [33529]
# /Users/greatmaster/miniconda3/envs/oreilly-agents-test-env/lib/python3.10/site-packages/langchain_core/_api/deprecation.py:117: LangChainDeprecationWarning: The class `langchain_community.embeddings.openai.OpenAIEmbeddings` was deprecated in langchain-community 0.0.9 and will be removed in 0.2.0. An updated version of the class exists in the langchain-openai package and should be used instead. To use it run `pip install -U langchain-openai` and import as `from langchain_openai import OpenAIEmbeddings`.
#   warn_deprecated(
# /Users/greatmaster/miniconda3/envs/oreilly-agents-test-env/lib/python3.10/site-packages/langchain_core/_api/deprecation.py:117: LangChainDeprecationWarning: The class `langchain_community.chat_models.openai.ChatOpenAI` was deprecated in langchain-community 0.0.10 and will be removed in 0.2.0. An updated version of the class exists in the langchain-openai package and should be used instead. To use it run `pip install -U langchain-openai` and import as `from langchain_openai import ChatOpenAI`.
#   warn_deprecated(
# INFO:     Started server process [33566]
# INFO:     Waiting for application startup.
#
#  __          ___      .__   __.   _______      _______. _______ .______     ____    ____  _______
# |  |        /   \     |  \ |  |  /  _____|    /       ||   ____||   _  \    \   \  /   / |   ____|
# |  |       /  ^  \    |   \|  | |  |  __     |   (----`|  |__   |  |_)  |    \   \/   /  |  |__
# |  |      /  /_\  \   |  . `  | |  | |_ |     \   \    |   __|  |      /      \      /   |   __|
# |  `----./  _____  \  |  |\   | |  |__| | .----)   |   |  |____ |  |\  \----.  \    /    |  |____
# |_______/__/     \__\ |__| \__|  \______| |_______/    |_______|| _| `._____|   \__/     |_______|
#
# LANGSERVE: Playground for chain "/rag-chroma/" is live at:
# LANGSERVE:  │
# LANGSERVE:  └──> /rag-chroma/playground/
# LANGSERVE:
# LANGSERVE: See all available routes at /docs/
#
# LANGSERVE: ⚠️ Using pydantic 2.6.4. OpenAPI docs for invoke, batch, stream, stream_log endpoints will not be generated. API endpoints and playground should work as expected. If you need to see the docs, you can downgrade to pydantic 1. For example, `pip install pydantic==1.10.13`. See https://github.com/tiangolo/fastapi/issues/10360 for details.
#
# INFO:     Application startup complete.
# ^C
# INFO:     Shutting down
# INFO:     Waiting for application shutdown.
# INFO:     Application shutdown complete.
# INFO:     Finished server process [33566]

# %% [markdown]
# Let's access our chat by going to:
#
# http://localhost:8000/rag-chroma/playground

# %% [markdown]
# To access the the template from code run this:
# (make sure to serve the app in a terminal first with the command shown previously).

# %%
from langserve.client import RemoteRunnable

runnable = RemoteRunnable("http://localhost:8000/rag-chroma")

# %%
runnable

# %%
runnable.invoke("What is it about?")
# Out:
# "The context provided suggests that the document is about Harrison's employment at Kensho."
