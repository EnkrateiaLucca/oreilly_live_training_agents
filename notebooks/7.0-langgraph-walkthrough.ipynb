# %%
# %pip install langchain
# %pip install langchain-core
# %pip install langchain-openai
# %pip install langgraph

# %%
# uncomment this if running locally
#!pip install python-dotenv
# from dotenv import load_dotenv

# load_dotenv()

# Or if you are in Colab, uncoment below and add your api key
import os
os.environ["OPENAI_API_KEY"] = "your-api-key"

# %%
from typing import Annotated, Literal, TypedDict
from langchain_core.messages import HumanMessage
from langchain_openai import ChatOpenAI
from langchain_core.tools import tool
from langgraph.checkpoint import MemorySaver
from langgraph.graph import END, StateGraph, MessagesState
from langgraph.prebuilt import ToolNode

# %%
import os
import requests
from bs4 import BeautifulSoup
# Tools: search and scraping an internet page
from langchain.tools import tool
from serpapi import GoogleSearch

serpapi_params = {
    "engine": "google",
    "api_key": os.environ["SERPAPI_KEY"]
}


@tool
def search_tool(query: str):
    """Searches the web given a user query and returns the most relevant links"""
    search = GoogleSearch({**serpapi_params, "q": query, "n": 5})
    output = search.get_dict()
    results = output["organic_results"]
    return [r["link"] for r in results]
    
@tool
def scrape_text(url: str):
    """Scrapes text from an internet page"""
    # source: copied from this script by Harrison Chase https://gist.github.com/hwchase17/69a8cdef9b01760c244324339ab64f0c
    try:
        response = requests.get(url)
        #check
        if response.status_code == 200:
            soup = BeautifulSoup(response.text, 'html.parser')
            # Extract all the text from the page
            page_text = soup.get_text(separator=" ", strip=True)
            
            return page_text
        else:
            return f"Failed to retrieve the webpage: Status code: {response.status_code}"
    
    except Exception as e:
        # In case of error print the error message
        print(e)
        return f"Failed to retrieve the webpage: {e}"

tools = [search_tool, scrape_text]
search_tool.invoke("Search the best resources to learn about how to make the best pancakes in the universe.")
# Out:
# ['https://www.thechoppingblock.com/blog/secrets-for-perfect-pancakes',
#  'https://www.kingarthurbaking.com/blog/2021/10/26/best-pancake-tips',
#  'https://cafedelites.com/best-fluffy-pancakes/',
#  'https://www.thekitchn.com/pancakes-recipe-263226',
#  'https://www.seriouseats.com/pancakes-around-the-world',
#  'https://www.marthastewart.com/338185/basic-pancakes']

# %%
search = GoogleSearch({**serpapi_params, "q": 'Pancakes', "n": 5})
output = search.get_dict()

output
# Out:
# {'search_metadata': {'id': '671bf2df8d04175308bc8ab5',
#   'status': 'Success',
#   'json_endpoint': 'https://serpapi.com/searches/54750f8cadcca7e2/671bf2df8d04175308bc8ab5.json',
#   'created_at': '2024-10-25 19:34:55 UTC',
#   'processed_at': '2024-10-25 19:34:55 UTC',
#   'google_url': 'https://www.google.com/search?q=Pancakes&oq=Pancakes&sourceid=chrome&ie=UTF-8',
#   'raw_html_file': 'https://serpapi.com/searches/54750f8cadcca7e2/671bf2df8d04175308bc8ab5.html',
#   'total_time_taken': 3.57},
#  'search_parameters': {'engine': 'google',
#   'q': 'Pancakes',
#   'google_domain': 'google.com',
#   'device': 'desktop'},
#  'search_information': {'query_displayed': 'Pancakes',
#   'total_results': 416000000,
#   'time_taken_displayed': 0.48,
#   'organic_results_state': 'Results for exact spelling'},
#  'recipes_results': [{'title': 'Good Old-Fashioned Pancakes',
#    'link': 'https://www.allrecipes.com/recipe/21014/good-old-fashioned-pancakes/',
#    'source': 'Allrecipes',
#    'rating': 4.5,
#    'reviews': 20000,
#    'total_time': '20 min',
#    'ingredients': ['Butter',
#     'egg',
#     'baking powder',
#     'all purpose flour',
#     'white sugar'],
#    'thumbnail': 'https://serpapi.com/searches/671bf2df8d04175308bc8ab5/images/be459b3e47df02c650feec8f6deacff5c7b1c67b19cde781159309097c9ba570.jpeg'},
#   {'title': 'Easy Fluffy Pancakes',
#    'link': 'https://www.inspiredtaste.net/24593/essential-pancake-recipe/',
#    'source': 'Inspired Taste',
#    'rating': 5.0,
#    'reviews': 458,
#    'total_time': '30 min',
#    'ingredients': ['Non dairy',
#     'egg',
#     'baking powder',
#     'sugar',
#     'all purpose flour'],
#    'thumbnail': 'https://serpapi.com/searches/671bf2df8d04175308bc8ab5/images/be459b3e47df02c650feec8f6deacff57a2bfcb9da44900fea2e04bd8ae82e86.jpeg'},
#   {'title': 'Best Fluffy Pancakes',
#    'link': 'https://cafedelites.com/best-fluffy-pancakes/',
#    'source': 'Cafe Delites',
#    'rating': 5.0,
#    'reviews': 724,
#    'total_time': '25 min',
#    'ingredients': ['Plain flour',
#     'egg',
#     'baking soda',
#     'baking powder',
#     'vanilla extract'],
#    'thumbnail': 'https://serpapi.com/searches/671bf2df8d04175308bc8ab5/images/be459b3e47df02c650feec8f6deacff5391b0cc030e55dafe9874403ce0b9c84.jpeg'}],
#  'local_map': {'link': 'https://www.google.com/search?sca_esv=dc67e9d40e314a2a&q=Pancakes&npsic=0&rflfq=1&rldoc=1&rllag=39311228,-104900468,53130&tbm=lcl&sa=X&ved=2ahUKEwjOgbe2o6qJAxU1xjgGHQaiMcwQtgN6BQiJARAC',
#   'image': 'https://serpapi.com/searches/671bf2df8d04175308bc8ab5/images/ba8a2897d3058ecb267f4930f53a3270.png',
#   'gps_coordinates': {'latitude': 39.311228, 'longitude': -104.900468}},
#  'local_results': {'places': [{'position': 1,
#     'rating': 4.5,
#     'reviews_original': '(953)',
#     'reviews': 953,
#     'description': '"Love all of their hash, the pancakes are always fluffy."',
#     'lsig': 'AB86z5VQV6D8013lGD-iKgPfuIT3',
#     'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipPU1c9WBtoiOXiYvZn1nwj6CdafQGiYeDYrOlsc=w92-h92-n-k-no',
#     'title': 'Cozy Cottage',
#     'type': 'Breakfast',
#     'address': 'Denver, CO',
#     'place_id': '3962888141140301318',
#     'place_id_search': 'https://serpapi.com/search.json?device=desktop&engine=google&google_domain=google.com&ludocid=3962888141140301318&q=Pancakes',
#     'gps_coordinates': {'latitude': 39.77589, 'longitude': -105.04438}},
#    {'position': 2,
#     'rating': 4.5,
#     'reviews_original': '(4.7K)',
#     'reviews': 4700,
#     'description': '"The pancake was large, fluffy and creamy."',
#     'lsig': 'AB86z5WWsFLVnzSU5IkMq2KBTv1x',
#     'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipMqPv0g1lQt1E-fK4deaOhUfgw9a7s0aODfCGHw=w92-h92-n-k-no',
#     'title': 'Black Bear Diner Colorado Springs - Academy',
#     'type': 'American',
#     'address': 'Colorado Springs, CO',
#     'place_id': '12489741040799385835',
#     'place_id_search': 'https://serpapi.com/search.json?device=desktop&engine=google&google_domain=google.com&ludocid=12489741040799385835&q=Pancakes',
#     'gps_coordinates': {'latitude': 38.846565, 'longitude': -104.75656}},
#    {'position': 3,
#     'rating': 4.6,
#     'reviews_original': '(2.8K)',
#     'reviews': 2800,
#     'description': '"Excellent pancakes, fresh juice, service was great, cute inside."',
#     'lsig': 'AB86z5V2MM6T7BtZhxJCWpZHmTsp',
#     'thumbnail': 'https://serpapi.com/searches/671bf2df8d04175308bc8ab5/images/857747504c123fb335de40243f312fe273d4f59e02947665e429f80ad208e4ad134b1e677ef04d34.jpeg',
#     'title': 'The Original Pancake House - DTC',
#     'type': 'Pancake',
#     'address': 'Greenwood Village, CO',
#     'hours': 'Closes soon ⋅ 2 PM',
#     'place_id': '12668302772118427812',
#     'place_id_search': 'https://serpapi.com/search.json?device=desktop&engine=google&google_domain=google.com&ludocid=12668302772118427812&q=Pancakes',
#     'gps_coordinates': {'latitude': 39.623543, 'longitude': -104.89606}}],
#   'more_locations_link': 'https://www.google.com/search?sca_esv=dc67e9d40e314a2a&tbm=lcl&q=Pancakes&rflfq=1&num=10&sa=X&ved=2ahUKEwjOgbe2o6qJAxU1xjgGHQaiMcwQjGp6BQiLARAB'},
#  'knowledge_graph': {'title': 'Pancake',
#   'type': 'Cake',
#   'entity_type': 'food, foods_and_dishes',
#   'kgmid': '/m/01dwwc',
#   'knowledge_graph_search_link': 'https://www.google.com/search?kgmid=/m/01dwwc&hl=en-US&q=Pancake',
#   'serpapi_knowledge_graph_search_link': 'https://serpapi.com/search.json?device=desktop&engine=google&google_domain=google.com&hl=en-US&kgmid=%2Fm%2F01dwwc&q=Pancake',
#   'header_images': [{'image': 'https://serpapi.com/searches/671bf2df8d04175308bc8ab5/images/af65b9619bf3c31a49b0c944ca1832ef389ba8415b4fb56e7b3afadd5ae5e140396661e3cb275776.jpeg',
#     'source': 'https://en.wikipedia.org/wiki/Pancake'},
#    {'image': 'https://serpapi.com/searches/671bf2df8d04175308bc8ab5/images/af65b9619bf3c31a49b0c944ca1832ef389ba8415b4fb56e3c4143c576ca50f8da6e77e3aa2a9ae5.jpeg',
#     'source': 'https://www.inspiredtaste.net/24593/essential-pancake-recipe/'},
#    {'image': 'https://serpapi.com/searches/671bf2df8d04175308bc8ab5/images/af65b9619bf3c31a49b0c944ca1832ef389ba8415b4fb56e43bcf7c0e025387767e8651111a5648f.jpeg',
#     'source': 'https://brokenovenbaking.com/easy-cinnamon-honey-pancakes/'},
#    {'image': 'https://serpapi.com/searches/671bf2df8d04175308bc8ab5/images/af65b9619bf3c31a49b0c944ca1832ef389ba8415b4fb56e6a3fc512fbaac85520974b5568181151.jpeg',
#     'source': 'https://www.thekitchn.com/pancakes-recipe-263226'},
#    {'image': 'https://serpapi.com/searches/671bf2df8d04175308bc8ab5/images/af65b9619bf3c31a49b0c944ca1832ef389ba8415b4fb56e9ffc2aa838e79394187158236a265d48.jpeg',
#     'source': 'https://www.marthastewart.com/338185/basic-pancakes'},
#    {'image': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQNWQD0aJU0c-aP-6ZWAM9xrF1qvtVv0_M1QvaD6gtqig&s',
#     'source': 'https://www.101cookbooks.com/pancake-recipe/'},
#    {'image': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQx4fpbBoS3RjAHp6sQICU1OoGzrmlnxVcHxGHsZfKRrQ&s',
#     'source': 'https://glutenfreebaking.com/gluten-free-pancakes/'}],
#   'description': 'A pancake, also known as hotcake, griddlecake, or flapjack, is a flat cake, often thin and round, prepared from a starch-based batter that may contain eggs, milk, and butter, and then cooked on a hot surface such as a griddle or frying pan. It is a type of batter bread.',
#   'source': {'name': 'Wikipedia',
#    'link': 'https://en.wikipedia.org/wiki/Pancake'},
#   'sources_include': 'USDAUSDAUSDAUSDAUSDAUSDAUSDAUSDAPancakes64 Calories - 1 oz (28.4 g)',
#   'sources_include_links': [{'text': 'USDA',
#     'link': 'https://fdc.nal.usda.gov/'},
#    {'text': 'USDA', 'link': 'https://fdc.nal.usda.gov/'},
#    {'text': 'USDA', 'link': 'https://fdc.nal.usda.gov/'},
#    {'text': 'USDA', 'link': 'https://fdc.nal.usda.gov/'},
#    {'text': 'USDA', 'link': 'https://fdc.nal.usda.gov/'},
#    {'text': 'USDA', 'link': 'https://fdc.nal.usda.gov/'},
#    {'text': 'USDA',
#     'link': 'https://fdc.nal.usda.gov/fdc-app.html#/food-details/173299/nutrients'},
#    {'text': 'USDA',
#     'link': 'https://fdc.nal.usda.gov/fdc-app.html#/food-details/175009/nutrients'}],
#   'people_also_search_for': [{'name': 'Crêpe',
#     'link': 'https://www.google.com/search?sca_esv=dc67e9d40e314a2a

#    'thumbnail': 'https://serpapi.com/searches/671bf2df8d04175308bc8ab5/images/fd234cf476bb04b9643bbe805d2206b77b03cc01dca233862e6db6b214b9d593.jpeg',
#    'original': 'https://upload.wikimedia.org/wikipedia/commons/4/40/Foodiesfeed.com_pouring-honey-on-pancakes-with-walnuts.jpg',
#    'title': 'upload.wikimedia.org/wikipedia/commons/4/40/Foodie...',
#    'source_name': 'en.wikipedia.org'},
#   {'link': 'https://www.google.com/search?q=Pancakes&sca_esv=dc67e9d40e314a2a&udm=2&source=iu&ictx=1&vet=1&fir=MgE_JLxJYDnQVM%252C1iFfPORO0R69TM%252C_%253BI4qzEwtHaAzy0M%252CbPMD0qJTdDy4TM%252C_%253BWikyZL0n3WMJCM%252Cfc9Y8mETWDsdFM%252C_%253B4kIXysbF94DFzM%252CS5qoaPhOpBe-qM%252C_%253B2SZnwxqu-qdf7M%252CEjDHuNwEgj-KsM%252C_%253BUm6mv881Tn50mM%252CmXQX70nAft-4hM%252C_%253BqUaclN7P2HAybM%252CIMxLtcbmbN3AQM%252C_&usg=AI4_-kQaS3eUAh--LoSDqCB4rsgfJGaNww&sa=X&ved=2ahUKEwjOgbe2o6qJAxU1xjgGHQaiMcwQ_h16BAg1EAE#vhid=I4qzEwtHaAzy0M&vssid=mosaic',
#    'source': 'https://www.inspiredtaste.net/24593/essential-pancake-recipe/',
#    'thumbnail': 'https://serpapi.com/searches/671bf2df8d04175308bc8ab5/images/fd234cf476bb04b9d346dafe61d7f0f1e1d5f8ca0112a0f13c66eb65c692f987.jpeg',
#    'original': 'https://www.inspiredtaste.net/wp-content/uploads/2024/03/Easy-Fluffy-Pancakes-Recipe-Video.jpg',
#    'title': 'Easy Fluffy Pancakes',
#    'source_name': 'Inspired Taste'},
#   {'link': 'https://www.google.com/search?q=Pancakes&sca_esv=dc67e9d40e314a2a&udm=2&source=iu&ictx=1&vet=1&fir=MgE_JLxJYDnQVM%252C1iFfPORO0R69TM%252C_%253BI4qzEwtHaAzy0M%252CbPMD0qJTdDy4TM%252C_%253BWikyZL0n3WMJCM%252Cfc9Y8mETWDsdFM%252C_%253B4kIXysbF94DFzM%252CS5qoaPhOpBe-qM%252C_%253B2SZnwxqu-qdf7M%252CEjDHuNwEgj-KsM%252C_%253BUm6mv881Tn50mM%252CmXQX70nAft-4hM%252C_%253BqUaclN7P2HAybM%252CIMxLtcbmbN3AQM%252C_&usg=AI4_-kQaS3eUAh--LoSDqCB4rsgfJGaNww&sa=X&ved=2ahUKEwjOgbe2o6qJAxU1xjgGHQaiMcwQ_h16BAg4EAE#vhid=WikyZL0n3WMJCM&vssid=mosaic',
#    'source': 'https://brokenovenbaking.com/easy-cinnamon-honey-pancakes/',
#    'thumbnail': 'https://serpapi.com/searches/671bf2df8d04175308bc8ab5/images/fd234cf476bb04b96e861e45b0372cce93e88305e89f576db940ce08876e339c.jpeg',
#    'original': 'https://brokenovenbaking.com/wp-content/uploads/2023/01/cinnamon-honey-pancakes-8-1.jpg',
#    'title': 'Easy Cinnamon Honey Pancakes',
#    'source_name': 'Broken Oven Baking'},
#   {'link': 'https://www.google.com/search?q=Pancakes&sca_esv=dc67e9d40e314a2a&udm=2&source=iu&ictx=1&vet=1&fir=MgE_JLxJYDnQVM%252C1iFfPORO0R69TM%252C_%253BI4qzEwtHaAzy0M%252CbPMD0qJTdDy4TM%252C_%253BWikyZL0n3WMJCM%252Cfc9Y8mETWDsdFM%252C_%253B4kIXysbF94DFzM%252CS5qoaPhOpBe-qM%252C_%253B2SZnwxqu-qdf7M%252CEjDHuNwEgj-KsM%252C_%253BUm6mv881Tn50mM%252CmXQX70nAft-4hM%252C_%253BqUaclN7P2HAybM%252CIMxLtcbmbN3AQM%252C_&usg=AI4_-kQaS3eUAh--LoSDqCB4rsgfJGaNww&sa=X&ved=2ahUKEwjOgbe2o6qJAxU1xjgGHQaiMcwQ_h16BAg2EAE#vhid=4kIXysbF94DFzM&vssid=mosaic',
#    'source': 'https://www.thekitchn.com/pancakes-recipe-263226',
#    'thumbnail': 'https://serpapi.com/searches/671bf2df8d04175308bc8ab5/images/fd234cf476bb04b9401770ef86ec9ffe7b7c5ac0ae5afe0e9b09e6928ad87f93.jpeg',
#    'original': 'https://cdn.apartmenttherapy.info/image/upload/f_auto,q_auto:eco,c_fill,g_auto,w_1500,ar_3:2/k%2FPhoto%2FRecipes%2F2024-06-seo-pancakes%2Fseo-pancakes-232',
#    'title': 'Fluffy Pancakes',
#    'source_name': 'The Kitchn'},
#   {'link': 'https://www.google.com/search?q=Pancakes&sca_esv=dc67e9d40e314a2a&udm=2&source=iu&ictx=1&vet=1&fir=MgE_JLxJYDnQVM%252C1iFfPORO0R69TM%252C_%253BI4qzEwtHaAzy0M%252CbPMD0qJTdDy4TM%252C_%253BWikyZL0n3WMJCM%252Cfc9Y8mETWDsdFM%252C_%253B4kIXysbF94DFzM%252CS5qoaPhOpBe-qM%252C_%253B2SZnwxqu-qdf7M%252CEjDHuNwEgj-KsM%252C_%253BUm6mv881Tn50mM%252CmXQX70nAft-4hM%252C_%253BqUaclN7P2HAybM%252CIMxLtcbmbN3AQM%252C_&usg=AI4_-kQaS3eUAh--LoSDqCB4rsgfJGaNww&sa=X&ved=2ahUKEwjOgbe2o6qJAxU1xjgGHQaiMcwQ_h16BAgyEAE#vhid=2SZnwxqu-qdf7M&vssid=mosaic',
#    'source': 'https://www.marthastewart.com/338185/basic-pancakes',
#    'thumbnail': 'https://serpapi.com/searches/671bf2df8d04175308bc8ab5/images/fd234cf476bb04b95220159d7d946985973e4a0c15cb1f53240c68b0fa2e88c2.jpeg',
#    'original': 'https://www.marthastewart.com/thmb/Vgb9cQSlegZz5fcoSbkkqyHPmHY=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/338185-basic-pancakes-09-00b18f8418fd4e52bb2050173d083d04.jpg',
#    'title': 'Easy Basic Pancakes',
#    'source_name': 'Martha Stewart'},
#   {'link': 'https://www.google.com/search?q=Pancakes&sca_esv=dc67e9d40e314a2a&udm=2&source=iu&ictx=1&vet=1&fir=MgE_JLxJYDnQVM%252C1iFfPORO0R69TM%252C_%253BI4qzEwtHaAzy0M%252CbPMD0qJTdDy4TM%252C_%253BWikyZL0n3WMJCM%252Cfc9Y8mETWDsdFM%252C_%253B4kIXysbF94DFzM%252CS5qoaPhOpBe-qM%252C_%253B2SZnwxqu-qdf7M%252CEjDHuNwEgj-KsM%252C_%253BUm6mv881Tn50mM%252CmXQX70nAft-4hM%252C_%253BqUaclN7P2HAybM%252CIMxLtcbmbN3AQM%252C_&usg=AI4_-kQaS3eUAh--LoSDqCB4rsgfJGaNww&sa=X&ved=2ahUKEwjOgbe2o6qJAxU1xjgGHQaiMcwQ_h16BAgzEAE#vhid=Um6mv881Tn50mM&vssid=mosaic',
#    'source': 'https://www.101cookbooks.com/pancake-recipe/',
#    'thumbnail': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQNWQD0aJU0c-aP-6ZWAM9xrF1qvtVv0_M1QvaD6gtqig&s',
#    'original': 'https://images.101cookbooks.com/FLUFFY-PANCAKE-RECIPE-H.jpg?w=1200&auto=compress&auto=format',
#    'title': 'Fluffy Pancakes',
#    'source_name': '101 Cookbooks'},
#   {'link': 'https://www.google.com/search?q=Pancakes&sca_esv=dc67e9d40e314a2a&udm=2&source=iu&ictx=1&vet=1&fir=MgE_JLxJYDnQVM%252C1iFfPORO0R69TM%252C_%253BI4qzEwtHaAzy0M%252CbPMD0qJTdDy4TM%252C_%253BWikyZL0n3WMJCM%252Cfc9Y8mETWDsdFM%252C_%253B4kIXysbF94DFzM%252CS5qoaPhOpBe-qM%252C_%253B2SZnwxqu-qdf7M%252CEjDHuNwEgj-KsM%252C_%253BUm6mv881Tn50mM%252CmXQX70nAft-4hM%252C_%253BqUaclN7P2HAybM%252CIMxLtcbmbN3AQM%252C_&usg=AI4_-kQaS3eUAh--LoSDqCB4rsgfJGaNww&sa=X&ved=2ahUKEwjOgbe2o6qJAxU1xjgGHQaiMcwQ_h16BAgxEAE#vhid=qUaclN7P2HAybM&vssid=mosaic',
#    'source': 'https://glutenfreebaking.com/gluten-free-pancakes/',
#    'thumbnail': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQx4fpbBoS3RjAHp6sQICU1OoGzrmlnxVcHxGHsZfKRrQ&s',
#    'original': 'https://glutenfreebaking.com/wp-content/uploads/2024/06/Stack-of-gluten-free-pancakes.jpg',
#    'title': 'Fluffy Gluten-Free Pancakes',
#    'source_name': 'Gluten-Free Baking -'}],
#  'inline_videos': [{'position': 1,
#    'title': 'The BEST Pancake Recipe',
#    'link': 'https://www.youtube.com/watch?v=qE5ycgqswGY',
#    'thumbnail': 'https://i.ytimg.com/vi/qE5ycgqswGY/mqdefault.jpg?sqp=-oaymwEFCJQBEFM&rs=AMzJL3lMuIGAVyelUl_U4gOEY8RuCtBKoQ',
#    'channel': 'Preppy Kitchen',
#    'duration': '7:48',
#    'date': 'Feb 27, 2024'},
#   {'position': 2,
#    'title': 'The Greatest Pancake Recipe of All Time (The GOAT)',
#    'link': 'https://www.youtube.com/watch?v=4QcK3MXl9sg',
#    'thumbnail': 'https://i.ytimg.com/vi/4QcK3MXl9sg/mqdefault.jpg?sqp=-oaymwEFCJQBEFM&rs=AMzJL3lpIPSaptA9F1S_21ClvafZgeJdQA',
#    'channel': 'Brian Lagerstrom',
#    'duration': '7:30',
#    'date': 'Jul 18, 2024',
#    'key_moments': [{'time': '00:00',
#      'title': 'Combining ingredients',
#      'link': 'https://www.youtube.com/watch?v=4QcK3MXl9sg&t=0',
#      'thumbnail': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQ-btmHZ12fjpzg4iTFXtNyX24oWPodFzLqY4xbwgcSHQ&s'},
#     {'time': '02:33',
#      'title': 'My jam (when it comes to daily nutrition)',
#      'link': 'https://www.youtube.com/watch?v=4QcK3MXl9sg&t=153',
#      'thumbnail': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTX-VcnmlzRvgk2561heRVSiI9VRnElv_qGdtyMkuGxow&s'},
#     {'time': '03:33',
#      'title': 'Cooking the pancakes',
#      'link': 'https://www.youtube.com/watch?v=4QcK3MXl9sg&t=213',
#      'thumbnail': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSNuj7rXZFpM8uDG6U-ax-fMFtg_myOK3v03tAa12ABXg&s'},
#     {'time': '06:37',
#      'title': 'What to do with leftover pancakes',
#      'link': 'https://www.youtube.com/watch?v=4QcK3MXl9sg&t=397',
#      'thumbnail': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQvu7qpCQgWo-Fdmz5u8vIUqgp5oPuW1AkjbNPC80QG0g&s'}]},
#   {'position': 3,
#    'title': "The Best Pancakes You'll Ever Make | Epicurious 101",
#    'link': 'https://www.youtube.com/watch?v=vkcHmpKxFwg',
#    'thumbnail': 'https://i.ytimg.com/vi/vkcHmpKxFwg/mqdefault.jpg?sqp=-oaymwEFCJQBEFM&rs=AMzJL3mC9uQBs9BAbwO-g3fVvCFEXEStog',
#    'channel': 'Epicurious',
#    'duration': '8:28',
#    'date': 'Dec 20, 2022',
#    'key_moments': [{'time': '00:35',
#      'title': 'Dry Ingredients',
#      'link': 'https://www.youtube.com/watch?v=vkcHmpKxFwg&t=35',
#      'thumbnail': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcR8-TsBMP5OlclIdR-eDkVQDcN1MwC29AeXhUWI1wdSPg&s'},
#     {'time': '01:00',
#      'title': 'Wet Ingredients',
#      'link': 'https://www.youtube.com/watch?v=vkcHmpKxFwg&t=60',
#      'thumbnail': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSoocYNOuWAKsX3xbrOGTjxkLl75y3pCoZNjkS2fEsYOA&s'},
#     {'time': '01:31',
#      'title': 'Eggs',
#      'link': 'https://www.youtube.com/watch?v=vkcHmpKxFwg&t=91',
#      'thumbnail': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSBfLtuFbV3xtVnf75PsAhHtwVTXGwnM10R7Pon9PvxQg&s'},
#     {'time': '03:55',
#      'title': 'Scooping Your Pancakes',
#      'link': 'https://www.youtube.com/watch?v=vkcHmpKxFwg&t=235',
#      'thumbnail': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRHmBR1D2DlMbYk3SzvHhD6FX909jyd_kFYTtBkK2pr7g&s'},
#     {'time': '06:50',
#      'title': 'Salted Whipped Butter',
#      'link': 'https://www.youtube.com/watch?v=vkcHmpKxFwg&t=410',
#      'thumbnail': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRNNkee8510B-KTok6cYKo54LgX3V5AkKJPmQRoG_Z_-w&s'}]}],
#  'related_questions': [{'question': 'What is the secret to good pancakes?',
#    'snippet': 'You want to stir until the batter is just combined, no more, no less. Overmixing leads to tough, chewy pancakes. Another step I like to take to achieve light and fluffy pancakes is to let the pancake batter rest on the countertop for 45 minutes to an hour before cooking.',
#    'title': 'Perfect Pancakes Recipe - The Pioneer Woman',
#    'date': 'Feb 14, 2024',
#    'link': 'https://www.thepioneerwoman.com/food-cooking/recipes/a11442/perfect-pancakes/#:~:text=You%20want%20to%20stir%20until,to%20an%20hour%20before%20cooking.',
#    'displayed_link': 'https://www.thepioneerwoman.com › recipes › perfect-p...',
#    'thumbnail': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQ-U-j5LX1Tf2pXLuMlRnph6ZDMC6ZA-UTgcyccROvRoQ&s',
#    'source_logo': 'https://serpapi.com/searches/671bf2df8d04175308bc8ab5/images/e83f722298a01e7bc8d8314e43dd4549ee13f6f9a1708d026890212bd08699fe.png',
#    'next_page_token': '...',
#    'serpapi_link': 'https://serpapi.com/search.json?device=desktop&engine=google_related_questions&google_domain=google.com&next_page_token=...%...'},
#   {'question': 'What are the ingredients for pancakes?',
#    'title': 'Ingredients',
#    'link': 'https://www.bbcgoodfood.com/recipes/easy-pancakes',
#    'list': ['100g plain flour.',
#     '2 large eggs.',
#     '300ml milk.',
#     '1 tbsp sunflower or vegetable oil, plus a little extra for frying.',
#     'lemon wedges, to serve (optional)',
#     'caster sugar, to serve (optional)'],
#    'displayed_link': 'https://www.bbcgoodfood.com › recipes › easy-pancakes',
#    'thumbnail': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQJV-2BaQaYNbD4Cu5jzSRECi7HBVJtJgb5N61vYIQoGw&s',
#    'source_logo': 'https://serpapi.com/searches/671bf2df8d04175308bc8ab5/images/e83f722298a01e7bc8d8314e43dd454946571cb8b44f07ac30b3f07616d47f60.png',
#    'next_page_token': '...',
#    'serpapi_link': 'https://serpapi.com/search.json?device=desktop&engine=google_related_questions&google_domain=google.com&next_page_token=...'},
#   {'question': 'Are pancakes healthy or unhealthy?',
#    'snippet': "Pancakes are a good source of riboflavin, calcium, and iron. However, they're relatively low in protein and fibre and high in carbohydrates and sugars. How can I make traditional pancakes healthier? It's fairly easy to make traditional pancakes a bit healthier.",
#    'title': 'Are Pancakes Healthy? - Mob',
#    'date': 'Apr 11, 2024',
#    'link': 'https://www.mob.co.uk/life/are-pancakes-healthy#:~:text=Pancakes%20are%20a%20good%20source,traditional%20pancakes%20a%20bit%20healthier.',
#    'displayed_link': 'https://www.mob.co.uk › life › are-pancakes-healthy',
#    'source_logo': 'https://serpapi.com/searches/671bf2df8d04175308bc8ab5/images/e83f722298a01e7bc8d8314e43dd4549894348516c99ae28fc08a19b65bab85a.png',
#    'next_page_token': '...',
#    'serpapi_link': 'https://serpapi.com/search.json?device=desktop&engine=google_related_questions&google_domain=google.com&next_page_token=...'},
#   {'question': 'Does milk instead of water make pancakes better?',
#    'snippet': 'Can you use milk instead of water for pancakes? You sure can! Instead of water, you can use any kind of milk, including almond milk and coconut milk, to mix up the pancake batter. Some Makers prefer the flavor of our pancakes when you use milk instead of water.',
#    'title': 'Tips For Making Perfect Pancakes - Krusteaz',
#    'link': 'https://www.krusteaz.com/tips-and-tricks/tips-for-making-krusteaz-pancakes/#:~:text=Can%20you%20use%20milk%20instead,use%20milk%20instead%20of%20water.',
#    'displayed_link': 'https://www.krusteaz.com › tips-and-tricks › tips-for-ma...',
#    'source_logo': 'https://serpapi.com/searches/671bf2df8d04175308bc8ab5/images/e83f722298a01e7bc8d8314e43dd45496163d14d4aa011558b537a67c1c69736.png',
#    'next_page_token': '...',
#    'serpapi_link': 'https://serpapi.com/search.json?device=desktop&engine=google_related_questions&google_domain=google.com&next_page_token=...%...%3D%3D'}],
#  'organic_results': [{'position': 1,
#    'title': 'Good Old-Fashioned Pancakes Recipe (with Video)',
#    'link': 'https://www.allrecipes.com/recipe/21014/good-old-fashioned-pancakes/',
#    'redirect_link': 'https://www.google.com/url?sa=t&source=web&rct=j&opi=89978449&url=https://www.allrecipes.com/recipe/21014/good-old-fashioned-pancakes/&ved=2ahUKEwjOgbe2o6qJAxU1xjgGHQaiMcwQFnoECAgQAQ',
#    'displayed_link': 'https://www.allrecipes.com › ... › Pancake Recipes',
#    'thumbnail': 'https://serpapi.com/searches/671bf2df8d04175308bc8ab5/images/c58df3a2d6ed0db790db46acb2c532a2a476b949d6145475af762378c8cf6ae5.jpeg',
#    'favicon': 'https://serpapi.com/searches/671bf2df8d04175308bc8ab5/images/c58df3a2d6ed0db790db46acb2c532a2c2d150fbf18143b22428f4f80a76bb99.png',
#    'date': 'Nov 29, 2022',
#    'snippet': 'This pancake recipe produces thick, fluffy, and all-around delicious pancakes with just a few ingredients that are probably already in your kitchen',
#    'snippet_highlighted_words': ['pancake', 'pancakes'],
#    'sitelinks': {'inline': [{'title': 'Authentic Swedish Pancakes',
#       'link': 'https://www.allrecipes.com/recipe/246952/authentic-swedish-pancakes/'},
#      {'title': 'Fluffy Keto Pancakes',
#       'link': 'https://www.allrecipes.com/recipe/259205/fluffy-keto-pancakes/'},
#      {'title': 'Traditional Swedish Pancakes',
#       'link': 'https://www.allrecipes.com/recipe/246954/traditional-swedish-pancakes/'}]},
#    'rich_snippet': {'bottom': {'detected_extensions': {'unknown': 4.5,
#       'min': 20},
#      'extensions': ['4.5(19,526)', '20 min']}},
#    'source': 'Allrecipes'},
#   {'position': 2,
#    'title': 'Easy Fluffy Pancakes Recipe',
#    'link': 'https://www.inspiredtaste.net/24593/essential-pancake-recipe/',
#    'redirect_link': 'https://www.google.com/url?sa=t&source=web&rct=j&opi=89978449&url=https://www.inspiredtaste.net/24593/essential-pancake-recipe/&ved=2ahUKEwjOgbe2o6qJAxU1xjgGHQaiMcwQFnoECBwQAQ',
#    'displayed_link': 'https://www.inspiredtaste.net › essential-pancake-recipe',
#    'thumbnail': 'https://serpapi.com/searches/671bf2df8d04175308bc8ab5/images/c58df3a2d6ed0db790db46acb2c532a2c8e19e31ee32116af74383d62d96e090.jpeg',
#    'favicon': 'https://serpapi.com/searches/671bf2df8d04175308bc8ab5/images/c58df3a2d6ed0db790db46acb2c532a2add0f578aac04841fcf5845ca17c28f9.png',
#    'snippet': "To make pancakes, you'll whisk the flour, baking powder, and salt in a large bowl. Then, whisk melted butter, milk, egg, and vanilla in another. Stir the wet ...",
#    'snippet_highlighted_words': ['pancakes'],
#    'rich_snippet': {'bottom': {'detected_extensions': {'unknown': 5.0,
#       'min': 30},
#      'extensions': ['5.0(458)', '30 min']}},
#    'source': 'Inspired Taste'},
#   {'position': 3,
#    'title': 'Everyday Pancakes - NYT Cooking',
#    'link': 'https://cooking.nytimes.com/recipes/1893-everyday-pancakes',
#    'redirect_link': 'https://www.google.com/url?sa=t&source=web&rct=j&opi=89978449&url=https://cooking.nytimes.com/recipes/1893-everyday-pancakes&ved=2ahUKEwjOgbe2o6qJAxU1xjgGHQaiMcwQFnoECB0QAQ',
#    'displayed_link': 'https://cooking.nytimes.com › recipes › 1893-everyday...',
#    'thumbnail': 'https://serpapi.com/searches/671bf2df8d04175308bc8ab5/images/c58df3a2d6ed0db790db46acb2c532a20873b6cf55ce39866ac4112b39edf127.jpeg',
#    'favicon': 'https://serpapi.com/searches/671bf2df8d04175308bc8ab5/images/c58df3a2d6ed0db790db46acb2c532a22f9ea1c0815c2621f65394a7876c79c7.png',
#    'date': 'Nov 14, 2023',
#    'snippet': 'The basic pancake is made from a simple batter of eggs, flour, milk and baking powder for leavening. You can use different types of flour if ...',
#    'snippet_highlighted_words': ['pancake'],
#    'rich_snippet': {'bottom': {'detected_extensions': {'unknown': 4.0,
#       'min': 20},
#      'extensions': ['4.0(13,332)', '20 min']}},
#    'source': 'NYT Cooking'},
#   {'position': 4,
#    'title': '[I ate] pistachio Soufflé pancakes : r/food',
#    'link': 'https://www.reddit.com/r/food/comments/1ga9qyr/i_ate_pistachio_souffl%C3%A9_pancakes/',
#    'redirect_link': 'https://www.google.com/url?sa=t&source=web&rct=j&opi=89978449&url=https://www.reddit.com/r/food/comments/1ga9qyr/i_ate_pistachio_souffl%25C3%25A9_pancakes/&ved=2ahUKEwjOgbe2o6qJAxU1xjgGHQaiMcwQFnoECEYQAQ',
#    'displayed_link': '30+ comments · 2 days ago',
#    'favicon': 'https://serpapi.com/searches/671bf2df8d04175308bc8ab5/images/c58df3a2d6ed0db790db46acb2c532a2509ca3013355dac40b5656b033107786.png',
#    'snippet': 'This is likely a Japanese souffle pancake, and if so, the browning is on the top and bottom.',
#    'snippet_highlighted_words': ['pancake'],
#    'source': 'Reddit · r/food'},
#   {'position': 5,
#    'title': 'Best Homemade Pancakes Recipe | How to Make Scratch ...',
#    'link': 'https://www.food.com/recipe/petes-scratch-pancakes-5170',
#    'redirect_link': 'https://www.google.com/url?sa=t&source=web&rct=j&opi=89978449&url=https://www.food.com/recipe/petes-scratch-pancakes-5170&ved=2ahUKEwjOgbe2o6qJAxU1xjgGHQaiMcwQFnoECEgQAQ',
#    'displayed_link': 'https://www.food.com › Recipes › Breakfast',
#    'thumbnail': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQoJ4bFQS_QNKfeelqdZsCuQcJaxmVxwdkDvc2Bl1PuzGohVQzXHfMx&usqp=CAE&s',
#    'favicon': 'https://serpapi.com/searches/671bf2df8d04175308bc8ab5/images/c58df3a2d6ed0db790db46acb2c532a22fc1b5918e2adeec0c22945493c1b995.png',
#    'snippet': 'ingredients · 2 cups flour · 3 tablespoons sugar · ⁄2 teaspoon salt · 1 tablespoon baking powder · 2 eggs, beat them separately before adding to mixture · ⁄4 ...',
#    'rich_snippet': {'bottom': {'detected_extensions': {'unknown': 5.0,
#       'min': 20},
#      'extensions': ['5.0(753)', '20 min']}},
#    'source': 'Food.com'},
#   {'position': 6,
#    'title': 'The BEST Fluffy Pancakes are so easy to make',
#    'link': 'https://cafedelites.com/best-fluffy-pancakes/',
#    'redirect_link': 'https://www.google.com/url?sa=t&source=web&rct=j&opi=89978449&url=https://cafedelites.com/best-fluffy-pancakes/&ved=2ahUKEwjOgbe2o6qJAxU1xjgGHQaiMcwQFnoECEsQAQ',
#    'displayed_link': 'https://cafedelites.com › Recipes',
#    'thumbnail': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQo246RfJn0vnGuepcZM7mEx1tIrhlaoVIL2_oGDPhLnZgpLAXkhXMK&usqp=CAE&s',
#    'favicon': 'https://serpapi.com/searches/671bf2df8d04175308bc8ab5/images/c58df3a2d6ed0db790db46acb2c532a2726a3d83654c6526db93687b40ecdb71.png',
#    'date': 'Jun 20, 2024',
#    'snippet': "A steaming stack of the world's Best Fluffy Pancakes are right here! Weekends will never be the same again. No buttermilk needed! SIMPLE. EASY. QUICK. FLUFFY.",
#    'snippet_highlighted_words': ['Pancakes'],
#    'sitelinks': {'inline': [{'title': 'Zebra Marble Pancakes',
#       'link': 'https://cafedelites.com/zebra-marble-pancakes/'},
#      {'title': 'Easy 3 Ingredient Pancakes',
#       'link': 'https://cafedelites.com/easy-3-ingredient-pancakes/'},
#      {'title': 'Save your favorite recipes!',
#       'link': 'https://cafedelites.com/your-collections/'}]},
#    'rich_snippet': {'bottom': {'detected_extensions': {'unknown': 5.0,
#       'min': 25},
#      'extensions': ['5.0(724)', '25 min']}},
#    'source': 'Cafe Delites'},
#   {'position': 7,
#    'title': 'Homemade Pancake Recipe',
#    'link': 'https://www.onceuponachef.com/recipes/best-pancake-recipe.html',
#    'redirect_link': 'https://www.google.com/url?sa=t&source=web&rct=j&opi=89978449&url=https://www.onceuponachef.com/recipes/best-pancake-recipe.html&ved=2ahUKEwjOgbe2o6qJAxU1xjgGHQaiMcwQFnoECEkQAQ',
#    'displayed_link': 'https://www.onceuponachef.com › recipes › best-panca...',
#    'thumbnail': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSgq5aIwYOxaTmtFVrP93MSzz7qU3TreLENej57RV1wGpgtyNlfa22g&usqp=CAE&s',
#    'favicon': 'https://serpapi.com/searches/671bf2df8d04175308bc8ab5/images/c58df3a2d6ed0db790db46acb2c532a2e3ceb76e6714d2879ce224773f3f6372.jpeg',
#    'date': 'Feb 12, 2024',
#    'snippet': 'TESTED & PERFECTED RECIPE - This easy pancake recipe makes the perfect pancakes: fluffy on the inside and crispy on the outside.',
#    'snippet_highlighted_words': ['pancake', 'pancakes'],
#    'sitelinks': {'inline': [{'title': 'Banana Pancakes',
#       'link': 'https://www.onceuponachef.com/recipes/banana-pancakes.html'},
#      {'title': 'Ricotta Pancakes',
#       'link': 'https://www.onceuponachef.com/recipes/ricotta-pancakes.html'},
#      {'title': 'Pumpkin Pancakes',
#       'link': 'https://www.onceuponachef.com/recipes/pumpkin-pancakes.html'},
#      {'title': 'Waffle Recipe',
#       'link': 'https://www.onceuponachef.com/recipes/waffle-recipe.html'}]},
#    'rich_snippet': {'bottom': {'detected_extensions': {'unknown': 4.7,
#       'min': 40},
#      'extensions': ['4.7(249)', '40 min']}},
#    'source': 'Once Upon a Chef'}],
#  'top_stories': [{'title': 'Frozen waffle recall over listeria risk expanded to include pancakes: See affected products',
#    'link': 'https://www.usatoday.com/story/money/food/2024/10/23/frozen-waffle-recall-list-expanded-pancakes-listeria/75805738007/',
#    'source': 'USA Today',
#    'date': '2 days ago',
#    'thumbnail': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSCQ1oH6GIOCFcl1__wp63yIseIMn1iugZQj_J_d9DuH4iyzj-H1_602rSCQA&usqp=CAI&s=10'},
#   {'title': 'Food safety investigation into Listeria in frozen waffles and pancakes leads to expanded recall',
#    'link': 'https://www.foodsafetynews.com/2024/10/food-safety-investigation-into-listeria-in-frozen-waffles-and-pancakes-leads-to-expanded-recall/',
#    'source': 'Food Safety News',
#    'date': '2 days ago',
#    'thumbnail': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcS-Jjr-xmwUq7K1Lbufm41wA9nexFk8RnkgdVN4CLyP-T8DIli2R0k1cC4&usqp=CAI&s'},
#   {'title': 'Listeria possibly linked to taco kits, waffles and pancakes',
#    'link': 'https://www.kjct8.com/2024/10/25/listeria-possibly-linked-taco-kits-waffles-pancakes/',
#    'source': 'KJCT',
#    'date': '3 hours ago',
#    'thumbnail': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTEm_Rbp0zObmL7uZ1cl3aw5lnl35aTFyiHnLV93zCMVw7yCdIDUzqUZiY&usqp=CAI&s'},
#   {'title': "Frozen Pancakes, Waffles From Trader Joe's, Whole Foods, and More Added to Widespread Recall",
#    'link': 'https://www.health.com/frozen-waffle-recall-expanded-listeria-risk-8733074',
#    'source': 'Health',
#    'date': '1 day ago',
#    'thumbnail': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcT3zhNfG8OgRklUw6JDb0fySU66ZsiIYF01iRrGrmKemtGb9Aa9nq7buOw&usqp=CAI&s'},
#   {'title': 'Wegmans recalls frozen waffles, pancakes over listeria concerns',
#    'link': 'https://www.rochesterfirst.com/news/recalls/wegmans-recalls-frozen-waffles-pancakes-over-listeria-concerns/',
#    'source': 'RochesterFirst',
#    'date': '2 days ago',
#    'thumbnail': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSZfMoSt1ZJ_JB_85tbtaNXTL6k8V6HZOTJCF7e_uthfvsOwiO63m8A1l8&usqp=CAI&s'},
#   {'title': 'Voboril: Come and get some pancakes',
#    'link': 'https://www.vaildaily.com/opinion/voboril-come-and-get-some-pancakes/',
#    'source': 'VailDaily.com',
#    'date': '2 hours ago',
#    'thumbnail': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSKPkTkXLLSFaMHGCAm6Gm0C4DbLqHWp0T76DavLRKTBvQyVrX_-zTePQo&usqp=CAI&s'},
#   {'title': "As a Wilmington club celebrates 50 years' worth of pancakes, here's what to know",
#    'link': 'https://www.starnewsonline.com/story/lifestyle/features/2024/10/25/wilmington-nc-kiwanis-pancake-breakfast-celebrates-50-years/75577216007/',
#    'source': 'Wilmington Star-News',
#    'date': '10 hours ago',
#    'thumbnail': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSh2Z7ztVGwtY-JfeVtB89UOlD3NqwXhCapxH2tskxLqjOrc-55Rn9McPA&usqp=CAI&s'}],
#  'top_stories_link': 'https://www.google.com/search?sca_esv=dc67e9d40e314a2a&tbm=lcl&q=Pancakes&rflfq=1&num=10&sa=X&ved=2ahUKEwjOgbe2o6qJAxU1xjgGHQaiMcwQjGp6BQiLARAB',
#  'top_stories_serpapi_link': 'https://serpapi.com/search.json?device=desktop&engine=google_local&gl=us&google_domain=google.com&hl=en&q=Pancakes',
#  'related_searches': [{'block_position': 1,
#    'query': 'Pancakes recipe',
#    'link': 'https://www.google.com/search?sca_esv=dc67e9d40e314a2a&q=Pancakes+recipe&sa=X&ved=2ahUKEwjOgbe2o6qJAxU1xjgGHQaiMcwQ1QJ6BQiDARAB',
#    'serpapi_link': 'https://serpapi.com/search.json?device=desktop&engine=google&google_domain=google.com&q=Pancakes+recipe'},
#   {'block_position': 1,
#    'query': 'Pancakes recipe easy',
#    'link': 'https://www.google.com/search?sca_esv=dc67e9d40e314a2a&q=Pancakes+recipe+easy&sa=X&ved=2ahUKEwjOgbe2o6qJAxU1xjgGHQaiMcwQ1QJ6BQiBARAB',
#    'serpapi_link': 'https://serpapi.com/search.json?device=desktop&engine=google&google_domain=google.com&q=Pancakes+recipe+easy'},
#   {'block_position': 1,
#    'query': 'Fluffy pancake recipe',
#    'link': 'https://www.google.com/search?sca_esv=dc67e9d40e314a2a&q=Fluffy+pancake+recipe&sa=X&ved=2ahUKEwjOgbe2o6qJAxU1xjgGHQaiMcwQ1QJ6BAh_EAE',
#    'serpapi_link': 'https://serpapi.com/search.json?device=desktop&engine=google&google_domain=google.com&q=Fluffy+pancake+recipe'},
#   {'block_position': 1,
#    'query': 'Pancakes without eggs',
#    'link': 'https://www.google.com/search?sca_esv=dc67e9d40e314a2a&q=Pancakes+without+eggs&sa=X&ved=2ahUKEwjOgbe2o6qJAxU1xjgGHQaiMcwQ1QJ6BAh6EAE',
#    'serpapi_link': 'https://serpapi.com/search.json?device=desktop&engine=google&google_domain=google.com&q=Pancakes+without+eggs'},
#   {'block_position': 1,
#    'query': 'Fluffy pancakes',
#    'link': 'https://www.google.com/search?sca_esv=dc67e9d40e314a2a&q=Fluffy+pancakes&sa=X&ved=2ahUKEwjOgbe2o6qJAxU1xjgGHQaiMcwQ1QJ6BAh5EAE',
#    'serpapi_link': 'https://serpapi.com/search.json?device=desktop&engine=google&google_domain=google.com&q=Fluffy+pancakes'},
#   {'block_position': 1,
#    'query': 'How to make pancakes step by step',
#    'link': 'https://www.google.com/search?sca_esv=dc67e9d40e314a2a&q=How+to+make+pancakes+step+by+step&sa=X&ved=2ahUKEwjOgbe2o6qJAxU1xjgGHQaiMcwQ1QJ6BAh0EAE',
#    'serpapi_link': 'https://serpapi.com/search.json?device=desktop&engine=google&google_domain=google.com&q=How+to+make+pancakes+step+by+step'},
#   {'block_position': 1,
#    'query': 'Buttermilk pancakes',
#    'link': 'https://www.google.com/search?sca_esv=dc67e9d40e314a2a&q=Buttermilk+pancakes&sa=X&ved=2ahUKEwjOgbe2o6qJAxU1xjgGHQaiMcwQ1QJ6BAhwEAE',
#    'serpapi_link': 'https://serpapi.com/search.json?device=desktop&engine=google&google_domain=google.com&q=Buttermilk+pancakes'},
#   {'block_position': 1,
#    'query': 'Pancake ingredients',
#    'link': 'https://www.google.com/search?sca_esv=dc67e9d40e314a2a&q=Pancake+ingredients&sa=X&ved=2ahUKEwjOgbe2o6qJAxU1xjgGHQaiMcwQ1QJ6BQiGARAB',
#    'serpapi_link': 'https://serpapi.com/search.json?device=desktop&engine=google&google_domain=google.com&q=Pancake+ingredients'}],
#  'pagination': {'current': 1,
#   'next': 'https://www.google.com/search?q=Pancakes&sca_esv=dc67e9d40e314a2a&ei=4fIbZ46NELWM4-EPhsTG4Qw&start=10&sa=N&sstk=AagrsuiqNT1WBN7l5A78_QeeySzin4cR2KD8D1tNR2BH0IobIKlwxK_NYBZPO6Pw27DDykdfgh4G4Rr4ciO0m_BujuGC4GkvSiOB1A&ved=2ahUKEwjOgbe2o6qJAxU1xjgGHQaiMcwQ8NMDegUIhwEQFg',
#   'other_pages': {'2': 'https://www.google.com/search?q=Pancakes&sca_esv=dc67e9d40e314a2a&ei=4fIbZ46NELWM4-EPhsTG4Qw&start=10&sa=N&sstk=AagrsuiqNT1WBN7l5A78_QeeySzin4cR2KD8D1tNR2BH0IobIKlwxK_NYBZPO6Pw27DDykdfgh4G4Rr4ciO0m_BujuGC4GkvSiOB1A&ved=2ahUKEwjOgbe2o6qJAxU1xjgGHQaiMcwQ8tMDegUIhwEQBA',
#    '3': 'https://www.google.com/search?q=Pancakes&sca_esv=dc67e9d40e314a2a&ei=4fIbZ46NELWM4-EPhsTG4Qw&start=20&sa=N&sstk=AagrsuiqNT1WBN7l5A78_QeeySzin4cR2KD8D1tNR2BH0IobIKlwxK_NYBZPO6Pw27DDykdfgh4G4Rr4ciO0m_BujuGC4GkvSiOB1A&ved=2ahUKEwjOgbe2o6qJAxU1xjgGHQaiMcwQ8tMDegUIhwEQBg',
#    '4': 'https://www.google.com/search?q=Pancakes&sca_esv=dc67e9d40e314a2a&ei=4fIbZ46NELWM4-EPhsTG4Qw&start=30&sa=N&sstk=AagrsuiqNT1WBN7l5A78_QeeySzin4cR2KD8D1tNR2BH0IobIKlwxK_NYBZPO6Pw27DDykdfgh4G4Rr4ciO0m_BujuGC4GkvSiOB1A&ved=2ahUKEwjOgbe2o6qJAxU1xjgGHQaiMcwQ8tMDegUIhwEQCA',
#    '5': 'https://www.google.com/search?q=Pancakes&sca_esv=dc67e9d40e314a2a&ei=4fIbZ46NELWM4-EPhsTG4Qw&start=40&sa=N&sstk=AagrsuiqNT1WBN7l5A78_QeeySzin4cR2KD8D1tNR2BH0IobIKlwxK_NYBZPO6Pw27DDykdfgh4G4Rr4ciO0m_BujuGC4GkvSiOB1A&ved=2ahUKEwjOgbe2o6qJAxU1xjgGHQaiMcwQ8tMDegUIhwEQCg',
#    '6': 'https://www.google.com/search?q=Pancakes&sca_esv=dc67e9d40e314a2a&ei=4fIbZ46NELWM4-EPhsTG4Qw&start=50&sa=N&sstk=AagrsuiqNT1WBN7l5A78_QeeySzin4cR2KD8D1tNR2BH0IobIKlwxK_NYBZPO6Pw27DDykdfgh4G4Rr4ciO0m_BujuGC4GkvSiOB1A&ved=2ahUKEwjOgbe2o6qJAxU1xjgGHQaiMcwQ8tMDegUIhwEQDA',
#    '7': 'https://www.google.com/search?q=Pancakes&sca_esv=dc67e9d40e314a2a&ei=4fIbZ46NELWM4-EPhsTG4Qw&start=60&sa=N&sstk=AagrsuiqNT1WBN7l5A78_QeeySzin4cR2KD8D1tNR2BH0IobIKlwxK_NYBZPO6Pw27DDykdfgh4G4Rr4ciO0m_BujuGC4GkvSiOB1A&ved=2ahUKEwjOgbe2o6qJAxU1xjgGHQaiMcwQ8tMDegUIhwEQDg',
#    '8': 'https://www.google.com/search?q=Pancakes&sca_esv=dc67e9d40e314a2a&ei=4fIbZ46NELWM4-EPhsTG4Qw&start=70&sa=N&sstk=AagrsuiqNT1WBN7l5A78_QeeySzin4cR2KD8D1tNR2BH0IobIKlwxK_NYBZPO6Pw27DDykdfgh4G4Rr4ciO0m_BujuGC4GkvSiOB1A&ved=2ahUKEwjOgbe2o6qJAxU1xjgGHQaiMcwQ8tMDegUIhwEQEA',
#    '9': 'https://www.google.com/search?q=Pancakes&sca_esv=dc67e9d40e314a2a&ei=4fIbZ46NELWM4-EPhsTG4Qw&start=80&sa=N&sstk=AagrsuiqNT1WBN7l5A78_QeeySzin4cR2KD8D1tNR2BH0IobIKlwxK_NYBZPO6Pw27DDykdfgh4G4Rr4ciO0m_BujuGC4GkvSiOB1A&ved=2ahUKEwjOgbe2o6qJAxU1xjgGHQaiMcwQ8tMDegUIhwEQEg',
#    '10': 'https://www.google.com/search?q=Pancakes&sca_esv=dc67e9d40e314a2a&ei=4fIbZ46NELWM4-EPhsTG4Qw&start=90&sa=N&sstk=AagrsuiqNT1WBN7l5A78_QeeySzin4cR2KD8D1tNR2BH0IobIKlwxK_NYBZPO6Pw27DDykdfgh4G4Rr4ciO0m_BujuGC4GkvSiOB1A&ved=2ahUKEwjOgbe2o6qJAxU1xjgGHQaiMcwQ8tMDegUIhwEQFA'}},
#  'serpapi_pagination': {'current': 1,
#   'next_link': 'https://serpapi.com/search.json?device=desktop&engine=google&google_domain=google.com&q=Pancakes&start=10',
#   'next': 'https://serpapi.com/search.json?device=desktop&engine=google&google_domain=google.com&q=Pancakes&start=10',
#   'other_pages': {'2': 'https://serpapi.com/search.json?device=desktop&engine=google&google_domain=google.com&q=Pancakes&start=10',
#    '3': 'https://serpapi.com/search.json?device=desktop&engine=google&google_domain=google.com&q=Pancakes&start=20',
#    '4': 'https://serpapi.com/search.json?device=desktop&engine=google&google_domain=google.com&q=Pancakes&start=30',
#    '5': 'https://serpapi.com/search.json?device=desktop&engine=google&google_domain=google.com&q=Pancakes&start=40',
#    '6': 'https://serpapi.com/search.json?device=desktop&engine=google&google_domain=google.com&q=Pancakes&start=50',
#    '7': 'https://serpapi.com/search.json?device=desktop&engine=google&google_domain=google.com&q=Pancakes&start=60',
#    '8': 'https://serpapi.com/search.json?device=desktop&engine=google&google_domain=google.com&q=Pancakes&start=70',
#    '9': 'https://serpapi.com/search.json?device=desktop&engine=google&google_domain=google.com&q=Pancakes&start=80',
#    '10': 'https://serpapi.com/search.json?device=desktop&engine=google&google_domain=google.com&q=Pancakes&start=90'}}}

# %%
tool_node = ToolNode(tools)

model = ChatOpenAI(model="gpt-4o", temperature=0).bind_tools(tools)

# Define the function that determines whether to continue or not
def should_continue(state: MessagesState) -> Literal["tools", END]:
    messages = state['messages']
    last_message = messages[-1]
    # If the LLM makes a tool call, then we route to the "tools" node
    if last_message.tool_calls:
        return "tools"
    # Otherwise, we stop (reply to the user)
    return END


# Define the function that calls the model
def call_model(state: MessagesState):
    messages = state['messages']
    response = model.invoke(messages)
    # We return a list, because this will get added to the existing list
    return {"messages": [response]}


# Define a new graph
workflow = StateGraph(MessagesState)

# Define the two nodes we will cycle between
workflow.add_node("agent", call_model)
workflow.add_node("tools", tool_node)

# Set the entrypoint as `agent`
# This means that this node is the first one called
workflow.set_entry_point("agent")

# We now add a conditional edge
workflow.add_conditional_edges(
    # First, we define the start node. We use `agent`.
    # This means these are the edges taken after the `agent` node is called.
    "agent",
    # Next, we pass in the function that will determine which node is called next.
    should_continue,
)

# We now add a normal edge from `tools` to `agent`.
# This means that after `tools` is called, `agent` node is called next.
workflow.add_edge("tools", 'agent')

# Initialize memory to persist state between graph runs
checkpointer = MemorySaver()

# Finally, we compile it!
# This compiles it into a LangChain Runnable,
# meaning you can use it as you would any other runnable.
# Note that we're (optionally) passing the memory when compiling the graph
app = workflow.compile(checkpointer=checkpointer)

# %%
from IPython.display import Image

Image(app.get_graph().draw_mermaid_png())

# %%
app.invoke({
    "messages": [
        HumanMessage(content="Search the web for articles about pancakes.")
        ],
    },config={"configurable": {"thread_id": 42}})
# Out:
# {'messages': [HumanMessage(content='Search the web for articles about pancakes.', id='e9f6a02e-69dc-46d2-b423-dd5b4cd88f83'),
#   AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_AtasVKEZd4FQC9lp9GgWhsKZ', 'function': {'arguments': '{"query":"articles about pancakes"}', 'name': 'search_tool'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 16, 'prompt_tokens':